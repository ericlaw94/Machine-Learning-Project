# %% [markdown]
# **Objective**
#
# The objective of this project is  to determine which basketball teams are most likely to make it to the semifinal round of the College Basketball Tournament known as the Final Four.
#
# **Introduction**
#
# In this scenario, as a Data Scientist working for a college basketball team. Your coaches have asked you to look at historical data to see which team metrics (individually or in combination) make a team more likely to make it into the Final Four. For example, if a team is more efficient defensively, does this have a direct relationship to their ability to get into the Final Four? What about defensively efficiency along with overall wins? Your job is to figure out if there is a combination of metrics that give a team more of a chance of making it into this tournament.
#
# Something to keep in mind is that when trying to predict results of basketball tournaments there are many variables that need to be taken into account. As a result of this creating accurate models is incredibly hard. In the sports betting industry an accuracy rate of anything over 55% is considered good as it indicates profits.
#
# I will load a historical data set from previous seasons, clean the data, and apply different classification algorithms to the data. These are the model i will be using for the analysis.
#
# - k-Nearest Neighbour
# - Decision Tree
# - Support Vector Machine
# - Logistic Regression
#
# The results are reported as the accuracy of each classifier, using the following metrics when applicable:
#
# - Jaccard index
# - F1-score
# - Accuracy

# %% [markdown]
# ### About dataset

# %% [markdown]
# You will have access to historical data and will apply different classification algorithms to accomplish this.
# This dataset is about the performance of basketball teams. The **cbb.csv** data set includes performance data about five seasons of 354 basketball teams. It includes following fields:
#
# | Field      | Description                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                    |
# | ---------- | ------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------ |
# | TEAM       | The Division I college basketball school                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                       |
# | CONF       | The Athletic Conference in which the school participates in (A10 = Atlantic 10, ACC = Atlantic Coast Conference, AE = America East, Amer = American, ASun = ASUN, B10 = Big Ten, B12 = Big 12, BE = Big East, BSky = Big Sky, BSth = Big South, BW = Big West, CAA = Colonial Athletic Association, CUSA = Conference USA, Horz = Horizon League, Ivy = Ivy League, MAAC = Metro Atlantic Athletic Conference, MAC = Mid-American Conference, MEAC = Mid-Eastern Athletic Conference, MVC = Missouri Valley Conference, MWC = Mountain West, NEC = Northeast Conference, OVC = Ohio Valley Conference, P12 = Pac-12, Pat = Patriot League, SB = Sun Belt, SC = Southern Conference, SEC = South Eastern Conference, Slnd = Southland Conference, Sum = Summit League, SWAC = Southwestern Athletic Conference, WAC = Western Athletic Conference, WCC = West Coast Conference) |
# | G          | Number of games played                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                         |
# | W          | Number of games won                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                            |
# | ADJOE      | Adjusted Offensive Efficiency (An estimate of the offensive efficiency (points scored per 100 possessions) a team would have against the average Division I defense)                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                           |
# | ADJDE      | Adjusted Defensive Efficiency (An estimate of the defensive efficiency (points allowed per 100 possessions) a team would have against the average Division I offense)                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                          |
# | BARTHAG    | Power Rating (Chance of beating an average Division I team)                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                    |
# | EFG_O      | Effective Field Goal Percentage Shot                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                           |
# | EFG_D      | Effective Field Goal Percentage Allowed                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                        |
# | TOR        | Turnover Percentage Allowed (Turnover Rate)                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                    |
# | TORD       | Turnover Percentage Committed (Steal Rate)                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                     |
# | ORB        | Offensive Rebound Percentage                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                   |
# | DRB        | Defensive Rebound Percentage                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                   |
# | FTR        | Free Throw Rate (How often the given team shoots Free Throws)                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                  |
# | FTRD       | Free Throw Rate Allowed                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                        |
# | 2P_O       | Two-Point Shooting Percentage                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                  |
# | 2P_D       | Two-Point Shooting Percentage Allowed                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                          |
# | 3P_O       | Three-Point Shooting Percentage                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                |
# | 3P_D       | Three-Point Shooting Percentage Allowed                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                        |
# | ADJ_T      | Adjusted Tempo (An estimate of the tempo (possessions per 40 minutes) a team would have against the team that wants to play at an average Division I tempo)                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                    |
# | WAB        | Wins Above Bubble (The bubble refers to the cut off between making the NCAA March Madness Tournament and not making it)                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                        |
# | POSTSEASON | Round where the given team was eliminated or where their season ended (R68 = First Four, R64 = Round of 64, R32 = Round of 32, S16 = Sweet Sixteen, E8 = Elite Eight, F4 = Final Four, 2ND = Runner-up, Champion = Winner of the NCAA March Madness Tournament for that given year)                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                            |
# | SEED       | Seed in the NCAA March Madness Tournament                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                      |
# | YEAR       | Season                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                         |

# %% [markdown]
# Lets first load required libraries:

# %%
import itertools
import numpy as np
import matplotlib.pyplot as plt
from matplotlib.ticker import NullFormatter
import pandas as pd
import numpy as np
import matplotlib.ticker as ticker
import seaborn as sns
from sklearn import preprocessing
# %matplotlib inline

# %% [markdown]
# ### Load Data From CSV File

# %% [markdown]
# Let's load the dataset [NB Need to provide link to csv file]

# %%
df = pd.read_csv('https://s3-api.us-geo.objectstorage.softlayer.net/cf-courses-data/CognitiveClass/ML0120ENv3/Dataset/ML0101EN_EDX_skill_up/cbb.csv')
df.head()
# Out:
#              TEAM CONF   G   W  ADJOE  ADJDE  BARTHAG  EFG_O  EFG_D   TOR  \
# 0  North Carolina  ACC  40  33  123.3   94.9   0.9531   52.6   48.1  15.4
# 1       Villanova   BE  40  35  123.1   90.9   0.9703   56.1   46.7  16.3
# 2      Notre Dame  ACC  36  24  118.3  103.3   0.8269   54.0   49.5  15.3
# 3        Virginia  ACC  37  29  119.9   91.0   0.9600   54.8   48.4  15.1
# 4          Kansas  B12  37  32  120.9   90.4   0.9662   55.7   45.1  17.8
#
#    ...  FTRD  2P_O  2P_D  3P_O  3P_D  ADJ_T   WAB  POSTSEASON  SEED  YEAR
# 0  ...  30.4  53.9  44.6  32.7  36.2   71.7   8.6         2ND   1.0  2016
# 1  ...  30.0  57.4  44.1  36.2  33.9   66.7   8.9   Champions   2.0  2016
# 2  ...  26.0  52.9  46.5  37.4  36.9   65.5   2.3          E8   6.0  2016
# 3  ...  33.4  52.6  46.3  40.3  34.7   61.9   8.6          E8   1.0  2016
# 4  ...  37.3  52.7  43.4  41.3  32.5   70.1  11.6          E8   1.0  2016
#
# [5 rows x 24 columns]

# %%
df.shape
# Out:
# (1406, 24)

# %% [markdown]
# ## Add Column
#
# Next we'll add a column that will contain "true" if the wins above bubble are over 7 and "false" if not. We'll call this column Win Index or "windex" for short.

# %%
df['windex'] = np.where(df.WAB > 7, 'True', 'False')
df
# Out:
#                 TEAM  CONF   G   W  ADJOE  ADJDE  BARTHAG  EFG_O  EFG_D   TOR  \
# 0     North Carolina   ACC  40  33  123.3   94.9   0.9531   52.6   48.1  15.4
# 1          Villanova    BE  40  35  123.1   90.9   0.9703   56.1   46.7  16.3
# 2         Notre Dame   ACC  36  24  118.3  103.3   0.8269   54.0   49.5  15.3
# 3           Virginia   ACC  37  29  119.9   91.0   0.9600   54.8   48.4  15.1
# 4             Kansas   B12  37  32  120.9   90.4   0.9662   55.7   45.1  17.8
# ...              ...   ...  ..  ..    ...    ...      ...    ...    ...   ...
# 1401         Houston  Amer  37  33  115.7   90.5   0.9439   52.1   42.5  16.5
# 1402        Michigan   B10  37  30  114.6   85.6   0.9665   51.6   44.1  13.9
# 1403          Oregon   P12  38  25  108.1   91.7   0.8687   52.0   46.4  17.8
# 1404             LSU   SEC  35  28  117.9   96.6   0.9081   51.2   49.9  17.9
# 1405       Tennessee   SEC  36  31  122.8   95.2   0.9488   55.3   48.1  15.8
#
#       ...  2P_O  2P_D  3P_O  3P_D  ADJ_T   WAB  POSTSEASON  SEED  YEAR  windex
# 0     ...  53.9  44.6  32.7  36.2   71.7   8.6         2ND   1.0  2016    True
# 1     ...  57.4  44.1  36.2  33.9   66.7   8.9   Champions   2.0  2016    True
# 2     ...  52.9  46.5  37.4  36.9   65.5   2.3          E8   6.0  2016   False
# 3     ...  52.6  46.3  40.3  34.7   61.9   8.6          E8   1.0  2016    True
# 4     ...  52.7  43.4  41.3  32.5   70.1  11.6          E8   1.0  2016    True
# ...   ...   ...   ...   ...   ...    ...   ...         ...   ...   ...     ...
# 1401  ...  51.3  43.0  35.5  27.9   67.3   7.8         S16   3.0  2019    True
# 1402  ...  51.8  44.3  34.2  29.1   65.9   9.2         S16   2.0  2019    True
# 1403  ...  51.6  48.8  35.1  29.0   65.4  -1.1         S16  12.0  2019   False
# 1404  ...  52.9  49.4  31.9  33.7   71.2   7.3         S16   3.0  2019    True
# 1405  ...  55.4  44.7  36.7  35.4   68.8   9.9         S16   2.0  2019    True
#
# [1406 rows x 25 columns]

# %% [markdown]
# # Data visualization and pre-processing

# %% [markdown]
# Next we'll filter the data set to the teams that made the Sweet Sixteen, the Elite Eight, and the Final Four in the post season. We'll also create a new dataframe that will hold the values with the new column.

# %%
df1 = df.loc[df['POSTSEASON'].str.contains('F4|S16|E8', na=False)] 
df1.head(50)
# Out:
#                 TEAM CONF   G   W  ADJOE  ADJDE  BARTHAG  EFG_O  EFG_D   TOR  \
# 2         Notre Dame  ACC  36  24  118.3  103.3   0.8269   54.0   49.5  15.3
# 3           Virginia  ACC  37  29  119.9   91.0   0.9600   54.8   48.4  15.1
# 4             Kansas  B12  37  32  120.9   90.4   0.9662   55.7   45.1  17.8
# 5             Oregon  P12  37  30  118.4   96.2   0.9163   52.3   48.9  16.1
# 6           Syracuse  ACC  37  23  111.9   93.6   0.8857   50.0   47.3  18.1
# 7           Oklahoma  B12  37  29  118.2   94.1   0.9326   54.3   47.2  18.3
# 343             Duke  ACC  36  25  121.2   98.9   0.9122   53.7   49.5  14.3
# 344         Miami FL  ACC  35  27  119.4   96.5   0.9203   54.2   48.3  16.5
# 345          Indiana  B10  35  27  121.3   98.4   0.9168   58.7   49.8  19.6
# 346         Maryland  B10  35  26  114.9   96.3   0.8839   55.2   46.5  18.9
# 347        Wisconsin  B10  35  22  108.8   93.5   0.8509   48.5   48.1  17.1
# 348         Iowa St.  B12  35  23  121.4   98.6   0.9162   57.1   49.8  15.7
# 349        Texas A&M  SEC  37  28  113.0   92.2   0.9126   51.2   47.4  17.4
# 350          Gonzaga  WCC  35  27  117.4   94.5   0.9238   55.2   44.8  17.1
# 353           Kansas  B12  36  31  121.5   94.5   0.9472   56.1   48.1  17.6
# 354           Xavier   BE  38  24  115.6   97.9   0.8713   51.9   51.6  18.4
# 355          Florida  SEC  36  27  116.6   88.9   0.9576   51.6   45.8  16.9
# 356         Kentucky  SEC  38  32  118.3   91.3   0.9517   52.9   47.5  15.7
# 357           Oregon  P12  38  33  117.8   93.8   0.9321   55.5   46.4  17.1
# 358   South Carolina  SEC  36  26  108.7   89.0   0.9083   47.3   45.5  18.4
# 694         Michigan  B10  38  26  123.3   97.6   0.9366   57.0   51.9  14.2
# 695           Purdue  B10  35  27  116.6   93.1   0.9297   55.7   47.7  18.3
# 696        Wisconsin  B10  37  27  114.5   92.0   0.9255   52.1   47.5  17.0
# 697           Baylor  B12  34  27  116.4   93.9   0.9226   52.5   46.1  20.6
# 698    West Virginia  B12  37  28  115.4   89.3   0.9498   51.3   48.8  17.0
# 699           Butler   BE  34  25  117.7   96.9   0.9038   54.6   50.8  15.0
# 700          Arizona  P12  37  32  117.6   95.6   0.9157   53.7   47.7  16.6
# 701             UCLA  P12  36  31  122.8   99.6   0.9175   59.8   48.7  15.1
# 704             Duke  ACC  37  29  122.3   92.9   0.9592   55.9   46.4  17.5
# 705      Florida St.  ACC  35  23  113.2   96.4   0.8631   53.2   48.4  17.8
# 706       Kansas St.  B12  37  25  109.6   93.7   0.8584   52.6   49.1  17.2
# 707       Texas Tech  B12  37  27  112.7   91.5   0.9170   52.0   46.4  17.8
# 708           Kansas  B12  39  31  122.1   96.4   0.9385   57.5   49.1  16.6
# 709   Loyola Chicago  MVC  37  32  110.5   95.4   0.8444   57.7   47.4  19.1
# 1045         Clemson  ACC  35  25  112.5   93.1   0.8984   52.9   47.2  17.4
# 1046        Syracuse  ACC  37  23  106.0   92.1   0.8344   46.9   46.2  19.1
# 1047          Purdue  B10  37  30  123.2   95.7   0.9484   57.7   47.0  15.8
# 1048   West Virginia  B12  37  26  120.9   95.8   0.9353   50.4   49.9  16.5
# 1049          Nevada  MWC  37  29  118.9  102.5   0.8462   54.8   49.4  13.5
# 1050        Kentucky  SEC  37  26  115.8   95.6   0.9000   51.8   46.8  18.6
# 1051       Texas A&M  SEC  35  22  111.2   94.7   0.8640   51.4   46.9  19.2
# 1052         Gonzaga  WCC  37  32  117.2   94.9   0.9192   57.0   47.1  16.1
# 1055            Duke  ACC  38  32  118.9   89.2   0.9646   53.6   45.0  17.5
# 1056          Purdue  B10  36  26  122.8   94.3   0.9539   53.6   49.0  15.8
# 1057        Kentucky  SEC  37  30  117.5   89.8   0.9568   53.0   46.6  18.6
# 1058         Gonzaga  WCC  37  33  123.4   89.9   0.9744   59.0   44.2  14.9
# 1059    Michigan St.  B10  39  32  119.9   91.0   0.9597   55.2   43.9  18.5
# 1060          Auburn  SEC  39  30  121.3   95.2   0.9420   54.4   51.7  16.8
# 1398     Florida St.  ACC  37  29  111.7   90.9   0.9146   50.5   47.2  18.9
# 1399  North Carolina  ACC  36  29  120.1   91.4   0.9582   52.9   48.9  17.2
#
#       ...  2P_O  2P_D  3P_O  3P_D  ADJ_T   WAB  POSTSEASON  SEED  YEAR  windex
# 2     ...  52.9  46.5  37.4  36.9   65.5   2.3          E8   6.0  2016   False
# 3     ...  52.6  46.3  40.3  34.7   61.9   8.6          E8   1.0  2016    True
# 4     ...  52.7  43.4  41.3  32.5   70.1  11.6          E8   1.0  2016    True
# 5     ...  52.6  46.1  34.4  36.2   69.0   6.7          E8   1.0  2016   False
# 6     ...  47.2  48.1  36.0  30.7   65.5  -0.3          F4  10.0  2016   False
# 7     ...  48.2  45.3  42.2  33.7   70.8   8.0          F4   2.0  2016    True
# 343   ...  51.0  48.9  38.5  34.0   68.7   4.2         S16   4.0  2016   False
# 344   ...  53.2  46.9  37.5  34.4   67.0   6.9         S16   3.0  2016   False
# 345   ...  56.1  49.0  41.6  34.3   69.5   3.2         S16   5.0  2016   False
# 346   ...  55.8  45.5  36.2  32.1   67.9   4.0         S16   5.0  2016   False
# 347   ...  46.6  44.8  34.9  37.4   64.1   0.4         S16   7.0  2016   False
# 348   ...  56.7  49.5  38.7  33.5   72.3   3.6         S16   3.0  2016   False
# 349   ...  51.3  45.6  34.1  33.3   68.4   5.2         S16   3.0  2016   False
# 350   ...  54.3  44.4  37.8  30.3   68.2   2.1         S16  11.0  2016   False
# 353   ...  53.6  45.3  40.4  35.6   71.4  11.0          E8   1.0  2017    True
# 354   ...  52.0  52.5  34.5  33.4   68.4   1.6          E8  11.0  2017   False
# 355   ...  50.3  45.7  35.9  30.5   70.2   6.4          E8   4.0  2017   False
# 356   ...  52.9  48.3  35.3  30.6   73.7   9.0          E8   2.0  2017    True
# 357   ...  54.5  46.1  38.0  31.2   68.4   6.0          F4   3.0  2017   False
# 358   ...  45.9  45.4  33.4  30.6   69.6   1.7          F4   7.0  2017   False
# 694   ...  56.3  50.0  38.5  37.8   64.0   3.8         S16   7.0  2017   False
# 695   ...  52.7  46.6  40.3  33.2   70.4   5.6         S16   4.0  2017   False
# 696   ...  51.1  43.1  35.9  37.6   64.4   5.1         S16   8.0  2017   False
# 697   ...  52.2  45.0  35.3  32.2   65.1   7.9         S16   3.0  2017    True
# 698   ...  49.8  46.5  36.2  35.3   72.2   6.4         S16   4.0  2017   False
# 699   ...  54.5  51.3  36.6  33.3   67.2   5.5         S16   4.0  2017   False
# 700   ...  51.5  48.4  39.0  31.0   67.1   7.9         S16   2.0  2017    True
# 701   ...  59.1  45.3  40.6  36.5   74.6   6.6         S16   3.0  2017   False
# 704   ...  56.0  45.4  37.2  32.0   70.9   6.6          E8   2.0  2018   False
# 705   ...  53.6  45.4  35.0  35.5   72.5   0.9          E8   9.0  2018   False
# 706   ...  53.4  48.9  34.1  33.0   66.5   2.5          E8   9.0  2018   False
# 707   ...  51.1  45.1  35.9  32.3   67.6   4.7          E8   3.0  2018   False
# 708   ...  55.6  48.6  40.1  33.3   69.9   8.2          F4   1.0  2018    True
# 709   ...  56.6  47.1  39.8  32.0   66.4   2.0          F4  11.0  2018   False
# 1045  ...  51.6  43.9  36.6  35.2   67.2   3.9         S16   5.0  2018   False
# 1046  ...  46.6  45.1  31.7  31.8   64.0  -0.4         S16  11.0  2018   False
# 1047  ...  54.1  45.5  42.0  33.2   68.7   7.6         S16   2.0  2018    True
# 1048  ...  48.8  45.4  35.3  38.0   71.2   4.6         S16   5.0  2018   False
# 1049  ...  52.1  50.7  39.2  31.7   70.7   2.5         S16   7.0  2018   False
# 1050  ...  51.2  48.0  35.7  30.1   70.0   4.3         S16   5.0  2018   False
# 1051  ...  52.5  45.7  32.9  32.6   70.3   1.9         S16   7.0  2018   False
# 1052  ...  58.2  44.1  36.8  35.0   70.5   4.9         S16   4.0  2018   False
# 1055  ...  58.0  45.0  30.8  29.9   73.6  11.2          E8   1.0  2019    True
# 1056  ...  51.5  47.2  37.4  34.2   67.0   6.1          E8   3.0  2019   False
# 1057  ...  52.9  43.6  35.4  34.3   66.9   8.8          E8   2.0  2019    True
# 1058  ...  61.4  43.4  36.3  30.4   72.0   7.0          E8   1.0  2019   False
# 1059  ...  54.3  41.9  37.8  31.6   68.6  10.7          F4   2.0  2019    True
# 1060  ...  51.7  51.4  38.1  34.8   69.3   6.1          F4   5.0  2019   False
# 1398  ...  50.9  45.3  33.2  33.5   70.0   7.6         S16   4.0  2019    True
# 1399  ...  52.1  47.9  36.2  33.5   76.0  10.0         S16   1.0  2019    True
#
# [50 rows x 25 columns]

# %%
df1['POSTSEASON'].value_counts()
# Out:
# S16    32
# E8     16
# F4      8
# Name: POSTSEASON, dtype: int64

# %% [markdown]
# 32 teams made it into the Sweet Sixteen, 16 into the Elite Eight, and 8 made it into the Final Four over 5 seasons.

# %% [markdown]
# Lets plot some columns to underestand data better:

# %%
# notice: installing seaborn might takes a few minutes
# !conda install -c anaconda seaborn -y
# Out:
# Collecting package metadata (current_repodata.json): done
# Solving environment: failed with initial frozen solve. Retrying with flexible solve.
# Solving environment: failed with repodata from current_repodata.json, will retry with next repodata source.
# Collecting package metadata (repodata.json): done
# Solving environment: failed with initial frozen solve. Retrying with flexible solve.
# Solving environment: done
#
# ## Package Plan ##
#
#   environment location: /opt/conda/envs/Python-3.7-main
#
#   added / updated specs:
#     - seaborn
#
#
# The following packages will be downloaded:
#
#     package                    |            build
#     ---------------------------|-----------------
#     _libgcc_mutex-0.1          |             main           3 KB  anaconda
#     _py-xgboost-mutex-2.0      |            cpu_0           9 KB  anaconda
#     _pytorch_select-0.1        |            cpu_0           2 KB  anaconda
#     absl-py-0.10.0             |           py37_0         169 KB  anaconda
#     aiohttp-3.6.3              |   py37h7b6447c_0         626 KB  anaconda
#     argon2-cffi-20.1.0         |   py37h7b6447c_1          49 KB  anaconda
#     astor-0.8.1                |           py37_0          45 KB  anaconda
#     astropy-4.0.2              |   py37h7b6447c_0         7.6 MB  anaconda
#     async-timeout-3.0.1        |           py37_0          12 KB  anaconda
#     async_generator-1.10       |   py37h28b3542_0          38 KB  anaconda
#     attrs-20.2.0               |             py_0          41 KB  anaconda
#     backcall-0.2.0             |             py_0          14 KB  anaconda
#     beautifulsoup4-4.9.3       |     pyhb0f4dca_0          87 KB  anaconda
#     biopython-1.78             |   py37h7b6447c_0         2.6 MB  anaconda
#     blas-1.0                   |              mkl           6 KB  anaconda
#     bleach-3.2.1               |             py_0         111 KB  anaconda
#     blinker-1.4                |           py37_0          21 KB  anaconda
#     blosc-1.19.0               |       hd408876_0          81 KB  anaconda
#     bokeh-2.2.3                |           py37_0         7.0 MB  anaconda
#     boto3-1.16.0               |             py_0          70 KB  anaconda
#     botocore-1.19.1            |             py_0         4.2 MB  anaconda
#     brotlipy-0.7.0             |py37h7b6447c_1000         348 KB  anaconda
#     bzip2-1.0.8                |       h7b6447c_0         105 KB  anaconda
#     c-ares-1.16.1              |       h7b6447c_0         112 KB  anaconda
#     ca-certificates-2020.10.14 |                0         128 KB  anaconda
#     cachetools-4.1.1           |             py_0          12 KB  anaconda
#     certifi-2020.6.20          |           py37_0         159 KB  anaconda
#     cffi-1.14.3                |   py37he30daa8_0         224 KB  anaconda
#     chardet-3.0.4              |        py37_1003         173 KB  anaconda
#     click-7.1.2                |             py_0          67 KB  anaconda
#     cloudpickle-1.6.0          |             py_0          29 KB  anaconda
#     cryptography-3.1.1         |   py37h1ba5d50_0         625 KB  anaconda
#     cx_oracle-8.0.1            |   py37h7b6447c_0         186 KB  anaconda
#     cycler-0.10.0              |           py37_0          13 KB  anaconda
#     cytoolz-0.11.0             |   py37h7b6447c_0         367 KB  anaconda
#     dask-core-2.30.0           |             py_0         639 KB  anaconda
#     dbus-1.13.18               |       hb2f20db_0         586 KB  anaconda
#     decorator-4.4.2            |             py_0          14 KB  anaconda
#     defusedxml-0.6.0           |             py_0          23 KB  anaconda
#     dill-0.3.2                 |             py_0          65 KB  anaconda
#     docutils-0.15.2            |           py37_0         736 KB  anaconda
#     entrypoints-0.3            |           py37_0          12 KB  anaconda
#     expat-2.2.10               |       he6710b0_2         192 KB  anaconda
#     fastcache-1.1.0            |   py37h7b6447c_0          31 KB  anaconda
#     fontconfig-2.13.0          |       h9420a91_0         291 KB  anaconda
#     freetds-1.00.97            |       h52ef933_0         2.4 MB  anaconda
#     freetype-2.10.4            |       h5ab3b9f_0         901 KB  anaconda
#     future-0.18.2              |           py37_1         720 KB  anaconda
#     gast-0.2.2                 |           py37_0         137 KB  anaconda
#     glib-2.56.2                |       hd408876_0         5.0 MB  anaconda
#     gmp-6.1.2                  |       hb3b607b_0         744 KB  anaconda
#     google-auth-1.22.1         |             py_0          62 KB  anaconda
#     google-auth-oauthlib-0.4.1 |             py_2          21 KB  anaconda
#     google-pasta-0.2.0         |             py_0          44 KB  anaconda
#     grpcio-1.31.0              |   py37hf8bcb03_0         2.2 MB  anaconda
#     gst-plugins-base-1.14.0    |       hbbd80ab_1         6.3 MB  anaconda
#     gstreamer-1.14.0           |       hb453b48_1         3.8 MB  anaconda
#     h5py-2.10.0                |   py37h7918eee_0         1.2 MB  anaconda
#     hdf5-1.10.4                |       hb1b8bf9_0         5.3 MB  anaconda
#     html5lib-1.1               |             py_0          92 KB  anaconda
#     ibm-wsrt-py37main-keep-0.0.0|             1629           2 KB
#     ibm-wsrt-py37main-main-custom|             1629           2 KB
#     icu-58.2                   |       he6710b0_3        22.7 MB  anaconda
#     idna-2.10                  |             py_0          56 KB  anaconda
#     imageio-2.9.0              |             py_0         3.1 MB  anaconda
#     importlib-metadata-2.0.0   |             py_1          35 KB  anaconda
#     importlib_metadata-2.0.0   |                1          11 KB  anaconda
#     iniconfig-1.1.1            |             py_0           8 KB  anaconda
#     intel-openmp-2020.2        |              254         947 KB  anaconda
#     ipykernel-5.3.4            |   py37h5ca1d4c_0         176 KB  anaconda
#     ipython-7.18.1             |   py37h5ca1d4c_0         1.1 MB  anaconda
#     ipython_genutils-0.2.0     |           py37_0          39 KB  anaconda
#     ipywidgets-7.5.1           |             py_1         102 KB  anaconda
#     jedi-0.17.2                |           py37_0         950 KB  anaconda
#     jeepney-0.4.3              |             py_0          22 KB  anaconda
#     jinja2-2.11.2              |             py_0          97 KB  anaconda
#     jmespath-0.10.0            |             py_0          22 KB  anaconda
#     joblib-0.17.0              |             py_0         205 KB  anaconda
#     jpeg-9b                    |       habf39ab_1         247 KB  anaconda
#     json5-0.9.5                |             py_0          22 KB  anaconda
#     jsonschema-3.2.0           |             py_2          45 KB  anaconda
#     jupyter_client-6.1.7       |             py_0          76 KB  anaconda
#     jupyter_core-4.6.3         |           py37_0          75 KB  anaconda
#     jupyterlab-2.2.6           |             py_0         5.9 MB  anaconda
#     jupyterlab_pygments-0.1.2  |             py_0           8 KB  anaconda
#     jupyterlab_server-1.2.0    |             py_0          24 KB  anaconda
#     keras-applications-1.0.8   |             py_1          30 KB  anaconda
#     keras-preprocessing-1.1.0  |             py_1          36 KB  anaconda
#     keyring-18.0.0             |           py37_0          55 KB  anaconda
#     kiwisolver-1.2.0           |   py37hfd86e86_0          91 KB  anaconda
#     krb5-1.17.1                |       h173b8e3_0         1.5 MB  anaconda
#     lcms2-2.11                 |       h396b838_0         419 KB  anaconda
#     ld_impl_linux-64-2.33.1    |       h53a641e_7         645 KB  anaconda
#     libedit-3.1.20191231       |       h14c3975_1         121 KB  anaconda
#     libffi-3.3                 |       he6710b0_2          54 KB  anaconda
#     libgcc-ng-9.1.0            |       hdf63c60_0         8.1 MB  anaconda
#     libgfortran-ng-7.3.0       |       hdf63c60_0         1.3 MB  anaconda
#     libpng-1.6.37              |       hbc83047_0         364 KB  anaconda
#     libpq-12.2                 |       h20c2e04_0         2.8 MB  anaconda
#     libprotobuf-3.13.0.1       |       hd408876_0         2.3 MB  anaconda
#     libsodium-1.0.18           |       h7b6447c_0         387 KB  anaconda
#     libstdcxx-ng-9.1.0         |       hdf63c60_0         4.0 MB  anaconda
#     libtiff-4.1.0              |       h2733197_1         607 KB  anaconda
#     libuuid-1.0.3              |       h1bed415_2          16 KB  anaconda
#     libxcb-1.14                |       h7b6447c_0         610 KB  anaconda
#     libxgboost-0.90            |       he6710b0_1         3.8 MB  anaconda
#     libxml2-2.9.10             |       hb55368b_3         1.3 MB  anaconda
#     libxslt-1.1.34             |       hc22bd24_0         573 KB  anaconda
#     lxml-4.6.1                 |   py37hefd8a0e_0         1.3 MB  anaconda
#     lz4-c-1.9.2                |       heb0550a_3         203 KB  anaconda
#     lzo-2.10                   |       h7b6447c_2         317 KB  anaconda
#     markdown-3.3.2             |           py37_0         123 KB  anaconda
#     markupsafe-1.1.1           |   py37h14c3975_1          26 KB  anaconda
#     matplotlib-3.3.1           |                0          24 KB  anaconda
#     matplotlib-base-3.3.1      |   py37h817c723_0         6.7 MB  anaconda
#     mistune-0.8.4              |py37h14c3975_1001          53 KB  anaconda
#     mkl-2019.4                 |              243       204.1 MB  anaconda
#     mkl-service-2.3.0          |   py37he904b0f_0         208 KB  anaconda
#     mkl_fft-1.2.0              |   py37h23d657b_0         164 KB  anaconda
#     mkl_random-1.1.0           |   py37hd6b4f25_0         376 KB  anaconda
#     mock-4.0.2                 |             py_0          31 KB  anaconda
#     more-itertools-8.5.0       |             py_0          42 KB  anaconda
#     mpmath-1.1.0               |           py37_0         957 KB  anaconda
#     multidict-4.7.6            |   py37h7b6447c_1          69 KB  anaconda
#     nbclient-0.5.1             |             py_0          60 KB  anaconda
#     nbconvert-6.0.7            |           py37_0         530 KB  anaconda
#     nbformat-5.0.8             |             py_0         101 KB  anaconda
#     ncurses-6.2                |       he6710b0_1         1.1 MB  anaconda
#     nest-asyncio-1.4.1         |             py_0          10 KB  anaconda
#     networkx-2.5               |             py_0         1.2 MB  anaconda
#     ninja-1.10.1               |   py37hfd86e86_0         1.9 MB  anaconda
#     nltk-3.5                   |             py_0         1.1 MB  anaconda
#     notebook-6.1.4             |           py37_0         6.3 MB  anaconda
#     numexpr-2.7.1              |   py37h423224d_0         197 KB  anaconda
#     numpy-1.19.1               |   py37hbc911f0_0          20 KB  anaconda
#     numpy-base-1.19.1          |   py37hfa32c7d_0         5.2 MB  anaconda
#     oauthlib-3.1.0             |             py_0          88 KB  anaconda
#     olefile-0.46               |           py37_0          48 KB  anaconda
#     openssl-1.1.1h             |       h7b6447c_0         3.8 MB  anaconda
#     opt_einsum-3.1.0           |             py_0          54 KB  anaconda
#     packaging-20.4             |             py_0          35 KB  anaconda
#     pandas-1.1.3               |   py37he6710b0_0        10.5 MB  anaconda
#     pandoc-2.11                |       hb0f4dca_0        12.5 MB  anaconda
#     pandocfilters-1.4.2        |           py37_1          13 KB  anaconda
#     parso-0.7.0                |             py_0          71 KB  anaconda
#     patsy-0.5.1                |           py37_0         375 KB  anaconda
#     pcre-8.44                  |       he6710b0_0         269 KB  anaconda
#     pexpect-4.8.0              |           py37_1          79 KB  anaconda
#     pickleshare-0.7.5          |        py37_1001          13 KB  anaconda
#     pillow-8.0.0               |   py37h9a89aac_0         686 KB  anaconda
#     pip-20.2.4                 |           py37_0         2.0 MB  anaconda
#     plotly-4.11.0              |             py_0         5.9 MB  anaconda
#     pluggy-0.13.1              |           py37_0          32 KB  anaconda
#     prometheus_client-0.8.0    |             py_0          48 KB  anaconda
#     prompt-toolkit-3.0.8       |             py_0         244 KB  anaconda
#     protobuf-3.13.0.1          |   py37he6710b0_1         700 KB  anaconda
#     psycopg2-2.8.5             |   py37h1ba5d50_0         172 KB  anaconda
#     ptyprocess-0.6.0           |           py37_0          23 KB  anaconda
#     py-1.9.0                   |             py_0          78 KB  anaconda
#     py-xgboost-0.90            |   py37he6710b0_1          77 KB  anaconda
#     pyasn1-0.4.8               |             py_0          58 KB  anaconda
#     pyasn1-modules-0.2.8       |             py_0          67 KB  anaconda
#     pycparser-2.20             |             py_2          94 KB  anaconda
#     pygments-2.7.1             |             py_0         704 KB  anaconda
#     pyjwt-1.7.1                |           py37_0          32 KB  anaconda
#     pymssql-2.1.5              |   py37h7b6447c_0         228 KB  anaconda
#     pyodbc-4.0.30              |   py37he6710b0_0          72 KB  anaconda
#     pyopenssl-19.1.0           |             py_1          47 KB  anaconda
#     pyparsing-2.4.7            |             py_0          64 KB  anaconda
#     pyqt-5.9.2                 |   py37h22d08a2_1         5.6 MB  anaconda
#     pyrsistent-0.17.3          |   py37h7b6447c_0          89 KB  anaconda
#     pyshp-2.1.0                |             py_0          34 KB  anaconda
#     pysocks-1.7.1              |           py37_1          27 KB  anaconda
#     pytables-3.6.1             |   py37h71ec239_0         1.5 MB  anaconda
#     pytest-6.1.1               |           py37_0         418 KB  anaconda
#     python-3.7.9               |       h7579374_0        52.8 MB  anaconda
#     python-dateutil-2.8.1      |             py_0         224 KB  anaconda
#     pytorch-1.5.0              |cpu_py37hd91cbb3_0        33.3 MB  anaconda
#     pytz-2020.1                |             py_0         239 KB  anaconda
#     pywavelets-1.1.1           |   py37h7b6447c_2         4.4 MB  anaconda
#     pyyaml-5.3.1               |   py37h7b6447c_1         191 KB  anaconda
#     pyzmq-19.0.2               |   py37he6710b0_1         499 KB  anaconda
#     qt-5.9.7                   |       h5867ecd_1        85.9 MB  anaconda
#     readline-8.0               |       h7b6447c_0         428 KB  anaconda
#     regex-2020.10.15           |   py37h7b6447c_0         358 KB  anaconda
#     requests-2.24.0            |             py_0          54 KB  anaconda
#     requests-oauthlib-1.3.0    |             py_0          22 KB  anaconda
#     retrying-1.3.3             |           py37_2          15 KB  anaconda
#     rsa-4.6                    |             py_0          26 KB  anaconda
#     s3transfer-0.3.3           |           py37_1          90 KB  anaconda
#     scikit-image-0.17.2        |   py37hdf5156a_0        10.7 MB  anaconda
#     scikit-learn-0.23.2        |   py37h0573a6f_0         6.9 MB  anaconda
#     scipy-1.5.2                |   py37h0b6359f_0        18.5 MB  anaconda
#     seaborn-0.11.0             |             py_0         216 KB  anaconda
#     secretstorage-3.1.2        |           py37_1          23 KB  anaconda
#     send2trash-1.5.0           |           py37_0          16 KB  anaconda
#     setuptools-50.3.0          |   py37hb0f4dca_1         904 KB  anaconda
#     sip-4.19.24                |   py37he6710b0_0         297 KB  anaconda
#     six-1.15.0                 |             py_0          13 KB  anaconda
#     snappy-1.1.8               |       he6710b0_0          43 KB  anaconda
#     snowballstemmer-2.0.0      |             py_0          58 KB  anaconda
#     soupsieve-2.0.1            |             py_0          33 KB  anaconda
#     sqlalchemy-1.3.19          |   py37h7b6447c_0         1.8 MB  anaconda
#     sqlite-3.33.0              |       h62c20be_0         2.0 MB  anaconda
#     statsmodels-0.12.0         |   py37h7b6447c_0        10.9 MB  anaconda
#     sympy-1.6.2                |           py37_0        10.5 MB  anaconda
#     tabulate-0.8.7             |           py37_0          40 KB  anaconda
#     tensorboard-2.1.0          |            py3_0         3.4 MB  anaconda
#     tensorflow-base-2.1.0      |mkl_py37h6d63fb7_0       166.1 MB  anaconda
#     tensorflow-estimator-2.1.0 |     pyhd54b08b_0         273 KB  anaconda
#     termcolor-1.1.0            |           py37_1           7 KB  anaconda
#     terminado-0.9.1            |           py37_0          26 KB  anaconda
#     testpath-0.4.4             |             py_0          88 KB  anaconda
#     threadpoolctl-2.1.0        |     pyh5ca1d4c_0          16 KB  anaconda
#     tifffile-2020.10.1         |   py37hdd07704_2         260 KB  anaconda
#     tk-8.6.10                  |       hbc83047_0         3.2 MB  anaconda
#     toml-0.10.1                |             py_0          20 KB  anaconda
#     toolz-0.11.1               |             py_0          47 KB  anaconda
#     tornado-6.0.4              |   py37h7b6447c_1         649 KB  anaconda
#     tqdm-4.50.2                |             py_0          55 KB  anaconda
#     traitlets-5.0.5            |             py_0          81 KB  anaconda
#     typing_extensions-3.7.4.3  |             py_0          29 KB  anaconda
#     unixodbc-2.3.9             |       h7b6447c_0         299 KB  anaconda
#     urllib3-1.25.11            |             py_0          93 KB  anaconda
#     wcwidth-0.2.5              |             py_0          37 KB  anaconda
#     webencodings-0.5.1         |           py37_1          19 KB  anaconda
#     werkzeug-1.0.1             |             py_0         243 KB  anaconda
#     wheel-0.35.1               |             py_0          36 KB  anaconda
#     widgetsnbextension-3.5.1   |           py37_0         1.8 MB  anaconda
#     wrapt-1.12.1               |   py37h7b6447c_1          50 KB  anaconda
#     xlrd-1.2.0                 |           py37_0         186 KB  anaconda
#     xlsxwriter-1.3.7           |             py_0         104 KB  anaconda
#     xz-5.2.5                   |       h7b6447c_0         438 KB  anaconda
#     yaml-0.2.5                 |       h7b6447c_0          87 KB  anaconda
#     yarl-1.6.2                 |   py37h7b6447c_0         139 KB  anaconda
#     zeromq-4.3.3               |       he6710b0_3         678 KB  anaconda
#     zipp-3.3.1                 |             py_0          11 KB  anaconda
#     zlib-1.2.11                |       h7b6447c_3         120 KB  anaconda
#     zstd-1.4.4                 |       h0b5b093_3        1006 KB  anaconda
#     ------------------------------------------------------------
#                                            Total:       821.4 MB
#
# The following NEW packages will be INSTALLED:
#
#   argon2-cffi        anaconda/linux-64::argon2-cffi-20.1.0-py37h7b6447c_1
#   async_generator    anaconda/linux-64::async_generator-1.10-py37h28b3542_0
#   ibm-wsrt-py37main~ opt/ibm/build/channels/wscloud/noarch::ibm-wsrt-py37main-keep-0.0.0-1629
#   iniconfig          anaconda/noarch::iniconfig-1.1.1-py_0
#   jupyterlab_pygmen~ anaconda/noarch::jupyterlab_pygments-0.1.2-py_0
#   nbclient           anaconda/noarch::nbclient-0.5.1-py_0
#   nest-asyncio       anaconda/noarch::nest-asyncio-1.4.1-py_0
#   tifffile           anaconda/linux-64::tifffile-2020.10.1-py37hdd07704_2
#   toml               anaconda/noarch::toml-0.10.1-py_0
#
# The following packages will be UPDATED:
#
#   absl-py                   pkgs/main::absl-py-0.9.0-py37_0 --> anaconda::absl-py-0.10.0-py37_0
#   aiohttp            pkgs/main::aiohttp-3.6.2-py37h7b6447c~ --> anaconda::aiohttp-3.6.3-py37h7b6447c_0
#   astor                       pkgs/main::astor-0.8.0-py37_0 --> anaconda::astor-0.8.1-py37_0
#   astropy            pkgs/main::astropy-4.0.1.post1-py37h7~ --> anaconda::astropy-4.0.2-py37h7b6447c_0
#   attrs                        pkgs/main::attrs-19.3.0-py_0 --> anaconda::attrs-20.2.0-py_0
#   beautifulsoup4     pkgs/main/linux-64::beautifulsoup4-4.~ --> anaconda/noarch::beautifulsoup4-4.9.3-pyhb0f4dca_0
#   biopython          pkgs/main::biopython-1.77-py37h7b6447~ --> anaconda::biopython-1.78-py37h7b6447c_0
#   bleach                       pkgs/main::bleach-3.1.5-py_0 --> anaconda::bleach-3.2.1-py_0
#   bokeh                       pkgs/main::bokeh-2.1.1-py37_0 --> anaconda::bokeh-2.2.3-py37_0
#   boto3                       pkgs/main::boto3-1.13.11-py_0 --> anaconda::boto3-1.16.0-py_0
#   botocore                 pkgs/main::botocore-1.16.11-py_0 --> anaconda::botocore-1.19.1-py_0
#   c-ares             pkgs/main::c-ares-1.15.0-h7b6447c_1001 --> anaconda::c-ares-1.16.1-h7b6447c_0
#   cffi                pkgs/main::cffi-1.14.0-py37he30daa8_1 --> anaconda::cffi-1.14.3-py37he30daa8_0
#   cloudpickle             pkgs/main::cloudpickle-1.5.0-py_0 --> anaconda::cloudpickle-1.6.0-py_0
#   cryptography       pkgs/main::cryptography-2.9.2-py37h1b~ --> anaconda::cryptography-3.1.1-py37h1ba5d50_0
#   cx_oracle          pkgs/main::cx_oracle-7.2.3-py37h7b644~ --> anaconda::cx_oracle-8.0.1-py37h7b6447c_0
#   cytoolz            pkgs/main::cytoolz-0.10.1-py37h7b6447~ --> anaconda::cytoolz-0.11.0-py37h7b6447c_0
#   dask-core                pkgs/main::dask-core-2.20.0-py_0 --> anaconda::dask-core-2.30.0-py_0
#   dbus                   pkgs/main::dbus-1.13.16-hb2f20db_0 --> anaconda::dbus-1.13.18-hb2f20db_0
#   dill                pkgs/main/linux-64::dill-0.3.0-py37_0 --> anaconda/noarch::dill-0.3.2-py_0
#   expat                   pkgs/main::expat-2.2.9-he6710b0_2 --> anaconda::expat-2.2.10-he6710b0_2
#   freetype            pkgs/main::freetype-2.10.2-h5ab3b9f_0 --> anaconda::freetype-2.10.4-h5ab3b9f_0
#   google-auth            pkgs/main::google-auth-1.22.0-py_0 --> anaconda::google-auth-1.22.1-py_0
#   grpcio             pkgs/main::grpcio-1.27.2-py37hf8bcb03~ --> anaconda::grpcio-1.31.0-py37hf8bcb03_0
#   gstreamer          pkgs/main::gstreamer-1.14.0-hb31296c_0 --> anaconda::gstreamer-1.14.0-hb453b48_1
#   idna                             pkgs/main::idna-2.9-py_1 --> anaconda::idna-2.10-py_0
#   importlib-metadata pkgs/main/linux-64::importlib-metadat~ --> anaconda/noarch::importlib-metadata-2.0.0-py_1
#   importlib_metadata  pkgs/main::importlib_metadata-1.6.1-0 --> anaconda::importlib_metadata-2.0.0-1
#   intel-openmp           pkgs/main::intel-openmp-2020.1-217 --> anaconda::intel-openmp-2020.2-254
#   ipykernel          pkgs/main::ipykernel-5.3.0-py37h5ca1d~ --> anaconda::ipykernel-5.3.4-py37h5ca1d4c_0
#   ipython                  pkgs/main::ipython-7.15.0-py37_0 --> anaconda::ipython-7.18.1-py37h5ca1d4c_0
#   jedi                        pkgs/main::jedi-0.17.1-py37_0 --> anaconda::jedi-0.17.2-py37_0
#   jeepney            pkgs/main/linux-64::jeepney-0.4-py37_0 --> anaconda/noarch::jeepney-0.4.3-py_0
#   jmespath                   pkgs/main::jmespath-0.9.4-py_0 --> anaconda::jmespath-0.10.0-py_0
#   joblib                      pkgs/main::joblib-0.16.0-py_0 --> anaconda::joblib-0.17.0-py_0
#   jupyter_client       pkgs/main::jupyter_client-6.1.3-py_0 --> anaconda::jupyter_client-6.1.7-py_0
#   jupyterlab_server  pkgs/main::jupyterlab_server-1.1.0-py~ --> anaconda::jupyterlab_server-1.2.0-py_0
#   libprotobuf        pkgs/main::libprotobuf-3.12.3-hd40887~ --> anaconda::libprotobuf-3.13.0.1-hd408876_0
#   lxml                 pkgs/main::lxml-4.5.1-py37hefd8a0e_0 --> anaconda::lxml-4.6.1-py37hefd8a0e_0
#   markdown                 pkgs/main::markdown-3.1.1-py37_0 --> anaconda::markdown-3.3.2-py37_0
#   matplotlib                  pkgs/main::matplotlib-3.2.2-0 --> anaconda::matplotlib-3.3.1-0
#   matplotlib-base    pkgs/main::matplotlib-base-3.2.2-py37~ --> anaconda::matplotlib-base-3.3.1-py37h817c723_0
#   mkl_fft            pkgs/main::mkl_fft-1.1.0-py37h23d657b~ --> anaconda::mkl_fft-1.2.0-py37h23d657b_0
#   more-itertools       pkgs/main::more-itertools-8.4.0-py_0 --> anaconda::more-itertools-8.5.0-py_0
#   nbconvert               pkgs/main::nbconvert-5.6.1-py37_1 --> anaconda::nbconvert-6.0.7-py37_0
#   nbformat                   pkgs/main::nbformat-5.0.7-py_0 --> anaconda::nbformat-5.0.8-py_0
#   networkx                     pkgs/main::networkx-2.4-py_1 --> anaconda::networkx-2.5-py_0
#   ninja               pkgs/main::ninja-1.9.0-py37hfd86e86_0 --> anaconda::ninja-1.10.1-py37hfd86e86_0
#   notebook                 pkgs/main::notebook-6.0.3-py37_0 --> anaconda::notebook-6.1.4-py37_0
#   numpy              pkgs/main::numpy-1.18.5-py37ha1c710e_0 --> anaconda::numpy-1.19.1-py37hbc911f0_0
#   numpy-base         pkgs/main::numpy-base-1.18.5-py37hde5~ --> anaconda::numpy-base-1.19.1-py37hfa32c7d_0
#   pandas             pkgs/main::pandas-1.0.5-py37h0573a6f_0 --> anaconda::pandas-1.1.3-py37he6710b0_0
#   pandoc                        pkgs/main::pandoc-2.9.2.1-0 --> anaconda::pandoc-2.11-hb0f4dca_0
#   pillow             pkgs/main::pillow-7.2.0-py37hb39fc2d_0 --> anaconda::pillow-8.0.0-py37h9a89aac_0
#   pip                          pkgs/main::pip-20.1.1-py37_1 --> anaconda::pip-20.2.4-py37_0
#   plotly                       pkgs/main::plotly-4.8.2-py_0 --> anaconda::plotly-4.11.0-py_0
#   prompt-toolkit       pkgs/main::prompt-toolkit-3.0.5-py_0 --> anaconda::prompt-toolkit-3.0.8-py_0
#   protobuf           pkgs/main::protobuf-3.12.3-py37he6710~ --> anaconda::protobuf-3.13.0.1-py37he6710b0_1
#   py                               pkgs/main::py-1.8.2-py_0 --> anaconda::py-1.9.0-py_0
#   pygments                   pkgs/main::pygments-2.6.1-py_0 --> anaconda::pygments-2.7.1-py_0
#   pyrsistent         pkgs/main::pyrsistent-0.16.0-py37h7b6~ --> anaconda::pyrsistent-0.17.3-py37h7b6447c_0
#   pytest             pkgs/main::pytest-5.4.3-py37h06a4308_0 --> anaconda::pytest-6.1.1-py37_0
#   pytorch            pkgs/main::pytorch-1.3.1-cpu_py37h62f~ --> anaconda::pytorch-1.5.0-cpu_py37hd91cbb3_0
#   pyzmq              pkgs/main::pyzmq-19.0.1-py37he6710b0_1 --> anaconda::pyzmq-19.0.2-py37he6710b0_1
#   regex              pkgs/main::regex-2020.6.8-py37h7b6447~ --> anaconda::regex-2020.10.15-py37h7b6447c_0
#   scikit-image       pkgs/main::scikit-image-0.16.2-py37h0~ --> anaconda::scikit-image-0.17.2-py37hdf5156a_0
#   scikit-learn       pkgs/main::scikit-learn-0.23.1-py37h4~ --> anaconda::scikit-learn-0.23.2-py37h0573a6f_0
#   scipy               pkgs/main::scipy-1.5.0-py37h0b6359f_0 --> anaconda::scipy-1.5.2-py37h0b6359f_0
#   seaborn                    pkgs/main::seaborn-0.10.1-py_0 --> anaconda::seaborn-0.11.0-py_0
#   secretstorage       pkgs/main::secretstorage-3.1.0-py37_0 --> anaconda::secretstorage-3.1.2-py37_1
#   setuptools            pkgs/main::setuptools-47.3.1-py37_0 --> anaconda::setuptools-50.3.0-py37hb0f4dca_1
#   sip                  pkgs/main::sip-4.19.8-py37hf484d3e_0 --> anaconda::sip-4.19.24-py37he6710b0_0
#   sqlalchemy         pkgs/main::sqlalchemy-1.3.17-py37h7b6~ --> anaconda::sqlalchemy-1.3.19-py37h7b6447c_0
#   statsmodels        pkgs/main::statsmodels-0.11.1-py37h7b~ --> anaconda::statsmodels-0.12.0-py37h7b6447c_0
#   tabulate                 pkgs/main::tabulate-0.8.3-py37_0 --> anaconda::tabulate-0.8.7-py37_0
#   terminado               pkgs/main::terminado-0.8.3-py37_0 --> anaconda::terminado-0.9.1-py37_0
#   toolz                        pkgs/main::toolz-0.10.0-py_0 --> anaconda::toolz-0.11.1-py_0
#   tqdm                          pkgs/main::tqdm-4.47.0-py_0 --> anaconda::tqdm-4.50.2-py_0
#   traitlets          pkgs/main/linux-64::traitlets-4.3.3-p~ --> anaconda/noarch::traitlets-5.0.5-py_0
#   typing_extensions  pkgs/main::typing_extensions-3.7.4.2-~ --> anaconda::typing_extensions-3.7.4.3-py_0
#   unixodbc             pkgs/main::unixodbc-2.3.7-h14c3975_0 --> anaconda::unixodbc-2.3.9-h7b6447c_0
#   urllib3                    pkgs/main::urllib3-1.25.9-py_0 --> anaconda::urllib3-1.25.11-py_0
#   wcwidth                     pkgs/main::wcwidth-0.2.4-py_0 --> anaconda::wcwidth-0.2.5-py_0
#   wheel              pkgs/main/linux-64::wheel-0.34.2-py37~ --> anaconda/noarch::wheel-0.35.1-py_0
#   xlsxwriter               pkgs/main::xlsxwriter-1.2.9-py_0 --> anaconda::xlsxwriter-1.3.7-py_0
#   yarl                 pkgs/main::yarl-1.5.1-py37h7b6447c_0 --> anaconda::yarl-1.6.2-py37h7b6447c_0
#   zeromq                 pkgs/main::zeromq-4.3.2-he6710b0_3 --> anaconda::zeromq-4.3.3-he6710b0_3
#   zipp                           pkgs/main::zipp-3.1.0-py_0 --> anaconda::zipp-3.3.1-py_0
#
# The following packages will be SUPERSEDED by a higher-priority channel:
#
#   _libgcc_mutex                                   pkgs/main --> anaconda
#   _py-xgboost-mutex                               pkgs/main --> anaconda
#   _pytorch_select                                 pkgs/main --> anaconda
#   async-timeout                                   pkgs/main --> anaconda
#   backcall                                        pkgs/main --> anaconda
#   blas                                            pkgs/main --> anaconda
#   blinker                                         pkgs/main --> anaconda
#   blosc                                           pkgs/main --> anaconda
#   brotlipy           pkgs/main::brotlipy-0.7.0-py37h27cfd2~ --> anaconda::brotlipy-0.7.0-py37h7b6447c_1000
#   bzip2                                           pkgs/main --> anaconda
#   ca-certificates                                 pkgs/main --> anaconda
#   cachetools                                      pkgs/main --> anaconda
#   certifi            pkgs/main::certifi-2020.11.8-py37h06a~ --> anaconda::certifi-2020.6.20-py37_0
#   chardet            pkgs/main::chardet-3.0.4-py37h06a4308~ --> anaconda::chardet-3.0.4-py37_1003
#   click                                           pkgs/main --> anaconda
#   cycler                                          pkgs/main --> anaconda
#   decorator                                       pkgs/main --> anaconda
#   defusedxml                                      pkgs/main --> anaconda
#   docutils                                        pkgs/main --> anaconda
#   entrypoints                                     pkgs/main --> anaconda
#   fastcache                                       pkgs/main --> anaconda
#   fontconfig                                      pkgs/main --> anaconda
#   freetds                                         pkgs/main --> anaconda
#   future                                          pkgs/main --> anaconda
#   gast                                            pkgs/main --> anaconda
#   glib                    pkgs/main::glib-2.65.0-h3eb4bd4_0 --> anaconda::glib-2.56.2-hd408876_0
#   gmp                       pkgs/main::gmp-6.1.2-h6c8ec71_1 --> anaconda::gmp-6.1.2-hb3b607b_0
#   google-auth-oauth~                              pkgs/main --> anaconda
#   google-pasta                                    pkgs/main --> anaconda
#   gst-plugins-base                                pkgs/main --> anaconda
#   h5py                                            pkgs/main --> anaconda
#   hdf5                                            pkgs/main --> anaconda
#   html5lib                                        pkgs/main --> anaconda
#   icu                                             pkgs/main --> anaconda
#   imageio                                         pkgs/main --> anaconda
#   ipython_genutils                                pkgs/main --> anaconda
#   ipywidgets                                      pkgs/main --> anaconda
#   jinja2                                          pkgs/main --> anaconda
#   jpeg                        pkgs/main::jpeg-9b-h024ee3a_2 --> anaconda::jpeg-9b-habf39ab_1
#   json5                                           pkgs/main --> anaconda
#   jsonschema                                      pkgs/main --> anaconda
#   jupyter_core                                    pkgs/main --> anaconda
#   jupyterlab                                      pkgs/main --> anaconda
#   keras-applications                              pkgs/main --> anaconda
#   keras-preprocessi~                              pkgs/main --> anaconda
#   keyring                                         pkgs/main --> anaconda
#   kiwisolver                                      pkgs/main --> anaconda
#   krb5                                            pkgs/main --> anaconda
#   lcms2                                           pkgs/main --> anaconda
#   ld_impl_linux-64                                pkgs/main --> anaconda
#   libedit                                         pkgs/main --> anaconda
#   libffi                                          pkgs/main --> anaconda
#   libgcc-ng                                       pkgs/main --> anaconda
#   libgfortran-ng                                  pkgs/main --> anaconda
#   libpng                                          pkgs/main --> anaconda
#   libpq                                           pkgs/main --> anaconda
#   libsodium                                       pkgs/main --> anaconda
#   libstdcxx-ng                                    pkgs/main --> anaconda
#   libtiff                                         pkgs/main --> anaconda
#   libuuid                                         pkgs/main --> anaconda
#   libxcb                                          pkgs/main --> anaconda
#   libxgboost                                      pkgs/main --> anaconda
#   libxml2                                         pkgs/main --> anaconda
#   libxslt                                         pkgs/main --> anaconda
#   lz4-c                                           pkgs/main --> anaconda
#   lzo                                             pkgs/main --> anaconda
#   markupsafe                                      pkgs/main --> anaconda
#   mistune                                         pkgs/main --> anaconda
#   mkl                             pkgs/main::mkl-2020.1-217 --> anaconda::mkl-2019.4-243
#   mkl-service                                     pkgs/main --> anaconda
#   mkl_random         pkgs/main::mkl_random-1.1.1-py37h0573~ --> anaconda::mkl_random-1.1.0-py37hd6b4f25_0
#   mock                                            pkgs/main --> anaconda
#   mpmath                                          pkgs/main --> anaconda
#   multidict                                       pkgs/main --> anaconda
#   ncurses                                         pkgs/main --> anaconda
#   nltk                                            pkgs/main --> anaconda
#   numexpr                                         pkgs/main --> anaconda
#   oauthlib                                        pkgs/main --> anaconda
#   olefile                                         pkgs/main --> anaconda
#   openssl                                         pkgs/main --> anaconda
#   opt_einsum                                      pkgs/main --> anaconda
#   packaging                                       pkgs/main --> anaconda
#   pandocfilters                                   pkgs/main --> anaconda
#   parso                                           pkgs/main --> anaconda
#   patsy                                           pkgs/main --> anaconda
#   pcre                                            pkgs/main --> anaconda
#   pexpect            pkgs/main/noarch::pexpect-4.8.0-pyhd3~ --> anaconda/linux-64::pexpect-4.8.0-py37_1
#   pickleshare                                     pkgs/main --> anaconda
#   pluggy                                          pkgs/main --> anaconda
#   prometheus_client                               pkgs/main --> anaconda
#   psycopg2                                        pkgs/main --> anaconda
#   ptyprocess         pkgs/main/noarch::ptyprocess-0.6.0-py~ --> anaconda/linux-64::ptyprocess-0.6.0-py37_0
#   py-xgboost                                      pkgs/main --> anaconda
#   pyasn1                                          pkgs/main --> anaconda
#   pyasn1-modules                                  pkgs/main --> anaconda
#   pycparser                                       pkgs/main --> anaconda
#   pyjwt                                           pkgs/main --> anaconda
#   pymssql                                         pkgs/main --> anaconda
#   pyodbc                                          pkgs/main --> anaconda
#   pyopenssl          pkgs/main::pyopenssl-19.1.0-pyhd3eb1b~ --> anaconda::pyopenssl-19.1.0-py_1
#   pyparsing                                       pkgs/main --> anaconda
#   pyqt                 pkgs/main::pyqt-5.9.2-py37h05f1152_2 --> anaconda::pyqt-5.9.2-py37h22d08a2_1
#   pyshp                                           pkgs/main --> anaconda
#   pysocks                                         pkgs/main --> anaconda
#   pytables                                        pkgs/main --> anaconda
#   python                                          pkgs/main --> anaconda
#   python-dateutil                                 pkgs/main --> anaconda
#   pytz                                            pkgs/main --> anaconda
#   pywavelets                                      pkgs/main --> anaconda
#   pyyaml                                          pkgs/main --> anaconda
#   qt                                              pkgs/main --> anaconda
#   readline                                        pkgs/main --> anaconda
#   requests                                        pkgs/main --> anaconda
#   requests-oauthlib                               pkgs/main --> anaconda
#   retrying                                        pkgs/main --> anaconda
#   rsa                                             pkgs/main --> anaconda
#   s3transfer                                      pkgs/main --> anaconda
#   send2trash                                      pkgs/main --> anaconda
#   six                pkgs/main/linux-64::six-1.15.0-py37h0~ --> anaconda/noarch::six-1.15.0-py_0
#   snappy                                          pkgs/main --> anaconda
#   snowballstemmer                                 pkgs/main --> anaconda
#   soupsieve                                       pkgs/main --> anaconda
#   sqlite                                          pkgs/main --> anaconda
#   sympy                                           pkgs/main --> anaconda
#   tensorboard                                     pkgs/main --> anaconda
#   tensorflow-base                                 pkgs/main --> anaconda
#   tensorflow-estima~                              pkgs/main --> anaconda
#   termcolor                                       pkgs/main --> anaconda
#   testpath                                        pkgs/main --> anaconda
#   threadpoolctl                                   pkgs/main --> anaconda
#   tk                                              pkgs/main --> anaconda
#   tornado                                         pkgs/main --> anaconda
#   webencodings                                    pkgs/main --> anaconda
#   werkzeug                                        pkgs/main --> anaconda
#   widgetsnbextension                              pkgs/main --> anaconda
#   wrapt                                           pkgs/main --> anaconda
#   xlrd                                            pkgs/main --> anaconda
#   xz                                              pkgs/main --> anaconda
#   yaml                                            pkgs/main --> anaconda
#   zlib                                            pkgs/main --> anaconda
#   zstd                                            pkgs/main --> anaconda
#
# The following packages will be DOWNGRADED:
#
#   ibm-wsrt-py37main~                             0.0.0-1629 --> custom-1629
#
#
#
# Downloading and Extracting Packages
# future-0.18.2        | 720 KB    | ##################################### | 100%
# nbconvert-6.0.7      | 530 KB    | ##################################### | 100%
# mkl-2019.4           | 204.1 MB  | ##################################### | 100%
# google-auth-1.22.1   | 62 KB     | ##################################### | 100%
# google-auth-oauthlib | 21 KB     | ##################################### | 100%
# yaml-0.2.5           | 87 KB     | ##################################### | 100%
# plotly-4.11.0        | 5.9 MB    | ##################################### | 100%
# boto3-1.16.0         | 70 KB     | ##################################### | 100%
# kiwisolver-1.2.0     | 91 KB     | ##################################### | 100%
# pygments-2.7.1       | 704 KB    | ##################################### | 100%
# keyring-18.0.0       | 55 KB     | ##################################### | 100%
# bokeh-2.2.3          | 7.0 MB    | ##################################### | 100%
# cycler-0.10.0        | 13 KB     | ##################################### | 100%
# prompt-toolkit-3.0.8 | 244 KB    | ##################################### | 100%
# jedi-0.17.2          | 950 KB    | ##################################### | 100%
# hdf5-1.10.4          | 5.3 MB    | ##################################### | 100%
# pyyaml-5.3.1         | 191 KB    | ##################################### | 100%
# testpath-0.4.4       | 88 KB     | ##################################### | 100%
# statsmodels-0.12.0   | 10.9 MB   | ##################################### | 100%
# markdown-3.3.2       | 123 KB    | ##################################### | 100%
# _libgcc_mutex-0.1    | 3 KB      | ##################################### | 100%
# jupyterlab_server-1. | 24 KB     | ##################################### | 100%
# libedit-3.1.20191231 | 121 KB    | ##################################### | 100%
# beautifulsoup4-4.9.3 | 87 KB     | ##################################### | 100%
# werkzeug-1.0.1       | 243 KB    | ##################################### | 100%
# mkl_fft-1.2.0        | 164 KB    | ##################################### | 100%
# pysocks-1.7.1        | 27 KB     | ##################################### | 100%
# threadpoolctl-2.1.0  | 16 KB     | ##################################### | 100%
# libstdcxx-ng-9.1.0   | 4.0 MB    | ##################################### | 100%
# gmp-6.1.2            | 744 KB    | ##################################### | 100%
# pyparsing-2.4.7      | 64 KB     |                                       |   0% WARNING conda.gateways.disk.delete:unlink_or_rename_to_trash(140): Could not remove or rename /opt/conda/pkgs/pyparsing-2.4.7-py_0/site-packages/pyparsing-2.4.7.dist-info/top_level.txt.  Please remove this file manually (you may need to reboot to free file handles)
# WARNING conda.gateways.disk.delete:unlink_or_rename_to_trash(140): Could not remove or rename /opt/conda/pkgs/pyparsing-2.4.7-py_0/site-packages/pyparsing-2.4.7.dist-info/RECORD.  Please remove this file manually (you may need to reboot to free file handles)
# WARNING conda.gateways.disk.delete:unlink_or_rename_to_trash(140): Could not remove or rename /opt/conda/pkgs/pyparsing-2.4.7-py_0/site-packages/pyparsing-2.4.7.dist-info/METADATA.  Please remove this file manually (you may need to reboot to free file handles)
# WARNING conda.gateways.disk.delete:unlink_or_rename_to_trash(140): Could not remove or rename /opt/conda/pkgs/pyparsing-2.4.7-py_0/site-packages/pyparsing-2.4.7.dist-info/WHEEL.  Please remove this file manually (you may need to reboot to free file handles)
# WARNING conda.gateways.disk.delete:unlink_or_rename_to_trash(140): Could not remove or rename /opt/conda/pkgs/pyparsing-2.4.7-py_0/site-packages/pyparsing-2.4.7.dist-info/LICENSE.  Please remove this file manually (you may need to reboot to free file handles)
# WARNING conda.gateways.disk.delete:unlink_or_rename_to_trash(140): Could not remove or rename /opt/conda/pkgs/pyparsing-2.4.7-py_0/site-packages/pyparsing-2.4.7.dist-info/INSTALLER.  Please remove this file manually (you may need to reboot to free file handles)
# WARNING conda.gateways.disk.delete:unlink_or_rename_to_trash(140): Could not remove or rename /opt/conda/pkgs/pyparsing-2.4.7-py_0/site-packages/pyparsing.py.  Please remove this file manually (you may need to reboot to free file handles)
# WARNING conda.gateways.disk.delete:unlink_or_rename_to_trash(140): Could not remove or rename /opt/conda/pkgs/pyparsing-2.4.7-py_0/info/recipe/meta.yaml.  Please remove this file manually (you may need to reboot to free file handles)
# WARNING conda.gateways.disk.delete:unlink_or_rename_to_trash(140): Could not remove or rename /opt/conda/pkgs/pyparsing-2.4.7-py_0/info/recipe/meta.yaml.template.  Please remove this file manually (you may need to reboot to free file handles)
# WARNING conda.gateways.disk.delete:unlink_or_rename_to_trash(140): Could not remove or rename /opt/conda/pkgs/pyparsing-2.4.7-py_0/info/recipe/recipe_log.txt.  Please remove this file manually (you may need to reboot to free file handles)
# WARNING conda.gateways.disk.delete:unlink_or_rename_to_trash(140): Could not remove or rename /opt/conda/pkgs/pyparsing-2.4.7-py_0/info/recipe/conda_build_config.yaml.  Please remove this file manually (you may need to reboot to free file handles)
# WARNING conda.gateways.disk.delete:unlink_or_rename_to_trash(140): Could not remove or rename /opt/conda/pkgs/pyparsing-2.4.7-py_0/info/licenses/LICENSE.  Please remove this file manually (you may need to reboot to free file handles)
# WARNING conda.gateways.disk.delete:unlink_or_rename_to_trash(140): Could not remove or rename /opt/conda/pkgs/pyparsing-2.4.7-py_0/info/test/run_test.bat.  Please remove this file manually (you may need to reboot to free file handles)
# WARNING conda.gateways.disk.delete:unlink_or_rename_to_trash(140): Could not remove or rename /opt/conda/pkgs/pyparsing-2.4.7-py_0/info/test/test_time_dependencies.json.  Please remove this file manually (you may need to reboot to free file handles)
# WARNING conda.gateways.disk.delete:unlink_or_rename_to_trash(140): Could not remove or rename /opt/conda/pkgs/pyparsing-2.4.7-py_0/info/test/run_test.sh.  Please remove this file manually (you may need to reboot to free file handles)
# WARNING conda.gateways.disk.delete:unlink_or_rename_to_trash(140): Could not remove or rename /opt/conda/pkgs/pyparsing-2.4.7-py_0/info/test/run_test.py.  Please remove this file manually (you may need to reboot to free file handles)
# WARNING conda.gateways.disk.delete:unlink_or_rename_to_trash(140): Could not remove or rename /opt/conda/pkgs/pyparsing-2.4.7-py_0/info/paths.json.  Please remove this file manually (you may need to reboot to free file handles)
# WARNING conda.gateways.disk.delete:unlink_or_rename_to_trash(140): Could not remove or rename /opt/conda/pkgs/pyparsing-2.4.7-py_0/info/files.  Please remove this file manually (you may need to reboot to free file handles)
# WARNING conda.gateways.disk.delete:unlink_or_rename_to_trash(140): Could not remove or rename /opt/conda/pkgs/pyparsing-2.4.7-py_0/info/repodata_record.json.  Please remove this file manually (you may need to reboot to free file handles)
# WARNING conda.gateways.disk.delete:unlink_or_rename_to_trash(140): Could not remove or rename /opt/conda/pkgs/pyparsing-2.4.7-py_0/info/git.  Please remove this file manually (you may need to reboot to free file handles)
# WARNING conda.gateways.disk.delete:unlink_or_rename_to_trash(140): Could not remove or rename /opt/conda/pkgs/pyparsing-2.4.7-py_0/info/index.json.  Please remove this file manually (you may need to reboot to free file handles)
# WARNING conda.gateways.disk.delete:unlink_or_rename_to_trash(140): Could not remove or rename /opt/conda/pkgs/pyparsing-2.4.7-py_0/info/about.json.  Please remove this file manually (you may need to reboot to free file handles)
# WARNING conda.gateways.disk.delete:unlink_or_rename_to_trash(140): Could not remove or rename /opt/conda/pkgs/pyparsing-2.4.7-py_0/info/link.json.  Please remove this file manually (you may need to reboot to free file handles)
# WARNING conda.gateways.disk.delete:unlink_or_rename_to_trash(140): Could not remove or rename /opt/conda/pkgs/pyparsing-2.4.7-py_0/info/hash_input.json.  Please remove this file manually (you may need to reboot to free file handles)
# WARNING conda.gateways.disk.delete:unlink_or_rename_to_trash(140): Could not remove or rename /opt/conda/pkgs/pyparsing-2.4.7-py_0/site-packages/pyparsing-2.4.7.dist-info/top_level.txt.  Please remove this file manually (you may need to reboot to free file handles)
# WARNING conda.gateways.disk.delete:unlink_or_rename_to_trash(140): Could not remove or rename /opt/conda/pkgs/pyparsing-2.4.7-py_0/site-packages/pyparsing-2.4.7.dist-info/RECORD.  Please remove this file manually (you may need to reboot to free file handles)
# ...
# WARNING conda.gateways.disk.delete:unlink_or_rename_to_trash(140): Could not remove or rename /opt/conda/pkgs/ncurses-6.2-he6710b0_1/lib/pkgconfig/ncursesw.pc.  Please remove this file manually (you may need to reboot to free file handles)
# WARNING conda.gateways.disk.delete:unlink_or_rename_to_trash(140): Could not remove or rename /opt/conda/pkgs/ncurses-6.2-he6710b0_1/lib/pkgconfig/tinfo.pc.  Please remove this file manually (you may need to reboot to free file handles)
# WARNING conda.gateways.disk.delete:unlink_or_rename_to_trash(140): Could not remove or rename /opt/conda/pkgs/ncurses-6.2-he6710b0_1/lib/pkgconfig/panel.pc.  Please remove this file manually (you may need to reboot to free file handles)
# WARNING conda.gateways.disk.delete:unlink_or_rename_to_trash(140): Could not remove or rename /opt/conda/pkgs/ncurses-6.2-he6710b0_1/lib/pkgconfig/ncurses++.pc.  Please remove this file manually (you may need to reboot to free file handles)
# WARNING conda.gateways.disk.delete:unlink_or_rename_to_trash(140): Could not remove or rename /opt/conda/pkgs/ncurses-6.2-he6710b0_1/lib/pkgconfig/formw.pc.  Please remove this file manually (you may need to reboot to free file handles)
# WARNING conda.gateways.disk.delete:unlink_or_rename_to_trash(140): Could not remove or rename /opt/conda/pkgs/ncurses-6.2-he6710b0_1/lib/libformw.so.  Please remove this file manually (you may need to reboot to free file handles)
# WARNING conda.gateways.disk.delete:unlink_or_rename_to_trash(140): Could not remove or rename /opt/conda/pkgs/ncurses-6.2-he6710b0_1/lib/libpanelw.so.  Please remove this file manually (you may need to reboot to free file handles)
# WARNING conda.gateways.disk.delete:unlink_or_rename_to_trash(140): Could not remove or rename /opt/conda/pkgs/ncurses-6.2-he6710b0_1/lib/libpanel.so.  Please remove this file manually (you may need to reboot to free file handles)
# WARNING conda.gateways.disk.delete:unlink_or_rename_to_trash(140): Could not remove or rename /opt/conda/pkgs/ncurses-6.2-he6710b0_1/lib/libformw.a.  Please remove this file manually (you may need to reboot to free file handles)
# WARNING conda.gateways.disk.delete:unlink_or_rename_to_trash(140): Could not remove or rename /opt/conda/pkgs/ncurses-6.2-he6710b0_1/lib/libncurses.a.  Please remove this file manually (you may need to reboot to free file handles)
# WARNING conda.gateways.disk.delete:unlink_or_rename_to_trash(140): Could not remove or rename /opt/conda/pkgs/ncurses-6.2-he6710b0_1/lib/libtinfo.a.  Please remove this file manually (you may need to reboot to free file handles)
# WARNING conda.gateways.disk.delete:unlink_or_rename_to_trash(140): Could not remove or rename /opt/conda/pkgs/ncurses-6.2-he6710b0_1/lib/libtinfow.so.6.  Please remove this file manually (you may need to reboot to free file handles)
# WARNING conda.gateways.disk.delete:unlink_or_rename_to_trash(140): Could not remove or rename /opt/conda/pkgs/ncurses-6.2-he6710b0_1/lib/libmenuw.so.  Please remove this file manually (you may need to reboot to free file handles)
# WARNING conda.gateways.disk.delete:unlink_or_rename_to_trash(140): Could not remove or rename /opt/conda/pkgs/ncurses-6.2-he6710b0_1/lib/libmenuw.so.6.  Please remove this file manually (you may need to reboot to free file handles)
# WARNING conda.gateways.disk.delete:unlink_or_rename_to_trash(140): Could not remove or rename /opt/conda/pkgs/ncurses-6.2-he6710b0_1/lib/libncurses.so.6.2.  Please remove this file manually (you may need to reboot to free file handles)
# WARNING conda.gateways.disk.delete:unlink_or_rename_to_trash(140): Could not remove or rename /opt/conda/pkgs/ncurses-6.2-he6710b0_1/lib/libmenuw.a.  Please remove this file manually (you may need to reboot to free file handles)
# WARNING conda.gateways.disk.delete:unlink_or_rename_to_trash(140): Could not remove or rename /opt/conda/pkgs/ncurses-6.2-he6710b0_1/lib/libtinfow.a.  Please remove this file manually (you may need to reboot to free file handles)
# WARNING conda.gateways.disk.delete:unlink_or_rename_to_trash(140): Could not remove or rename /opt/conda/pkgs/ncurses-6.2-he6710b0_1/lib/libform.so.6.2.  Please remove this file manually (you may need to reboot to free file handles)
# WARNING conda.gateways.disk.delete:unlink_or_rename_to_trash(140): Could not remove or rename /opt/conda/pkgs/ncurses-6.2-he6710b0_1/lib/libncurses++w.a.  Please remove this file manually (you may need to reboot to free file handles)
# WARNING conda.gateways.disk.delete:unlink_or_rename_to_trash(140): Could not remove or rename /opt/conda/pkgs/ncurses-6.2-he6710b0_1/lib/libform.so.  Please remove this file manually (you may need to reboot to free file handles)
# WARNING conda.gateways.disk.delete:unlink_or_rename_to_trash(140): Could not remove or rename /opt/conda/pkgs/ncurses-6.2-he6710b0_1/lib/libtinfow.so.6.2.  Please remove this file manually (you may need to reboot to free file handles)
# WARNING conda.gateways.disk.delete:unlink_or_rename_to_trash(140): Could not remove or rename /opt/conda/pkgs/ncurses-6.2-he6710b0_1/lib/libncurses.so.6.  Please remove this file manually (you may need to reboot to free file handles)
# WARNING conda.gateways.disk.delete:unlink_or_rename_to_trash(140): Could not remove or rename /opt/conda/pkgs/ncurses-6.2-he6710b0_1/lib/libform.a.  Please remove this file manually (you may need to reboot to free file handles)
# WARNING conda.gateways.disk.delete:unlink_or_rename_to_trash(140): Could not remove or rename /opt/conda/pkgs/ncurses-6.2-he6710b0_1/lib/libtinfo.so.6.2.  Please remove this file manually (you may need to reboot to free file handles)
# WARNING conda.gateways.disk.delete:unlink_or_rename_to_trash(140): Could not remove or rename /opt/conda/pkgs/ncurses-6.2-he6710b0_1/lib/libpanelw.so.6.2.  Please remove this file manually (you may need to reboot to free file handles)
# WARNING conda.gateways.disk.delete:unlink_or_rename_to_trash(140): Could not remove or rename /opt/conda/pkgs/ncurses-6.2-he6710b0_1/lib/libformw.so.6.  Please remove this file manually (you may need to reboot to free file handles)
# WARNING conda.gateways.disk.delete:unlink_or_rename_to_trash(140): Could not remove or rename /opt/conda/pkgs/ncurses-6.2-he6710b0_1/lib/libtinfo.so.6.  Please remove this file manually (you may need to reboot to free file handles)
# WARNING conda.gateways.disk.delete:unlink_or_rename_to_trash(140): Could not remove or rename /opt/conda/pkgs/ncurses-6.2-he6710b0_1/lib/libncursesw.so.6.2.  Please remove this file manually (you may need to reboot to free file handles)
# WARNING conda.gateways.disk.delete:unlink_or_rename_to_trash(140): Could not remove or rename /opt/conda/pkgs/ncurses-6.2-he6710b0_1/lib/libpanelw.so.6.  Please remove this file manually (you may need to reboot to free file handles)
# WARNING conda.gateways.disk.delete:unlink_or_rename_to_trash(140): Could not remove or rename /opt/conda/pkgs/ncurses-6.2-he6710b0_1/lib/libpanel.so.6.  Please remove this file manually (you may need to reboot to free file handles)
# WARNING conda.gateways.disk.delete:unlink_or_rename_to_trash(140): Could not remove or rename /opt/conda/pkgs/ncurses-6.2-he6710b0_1/lib/libform.so.6.  Please remove this file manually (you may need to reboot to free file handles)
# WARNING conda.gateways.disk.delete:unlink_or_rename_to_trash(140): Could not remove or rename /opt/conda/pkgs/ncurses-6.2-he6710b0_1/lib/libncurses++.a.  Please remove this file manually (you may need to reboot to free file handles)
# WARNING conda.gateways.disk.delete:unlink_or_rename_to_trash(140): Could not remove or rename /opt/conda/pkgs/ncurses-6.2-he6710b0_1/lib/libncurses.so.  Please remove this file manually (you may need to reboot to free file handles)
# WARNING conda.gateways.disk.delete:unlink_or_rename_to_trash(140): Could not remove or rename /opt/conda/pkgs/ncurses-6.2-he6710b0_1/lib/libpanel.so.6.2.  Please remove this file manually (you may need to reboot to free file handles)
# WARNING conda.gateways.disk.delete:unlink_or_rename_to_trash(140): Could not remove or rename /opt/conda/pkgs/ncurses-6.2-he6710b0_1/lib/libmenu.a.  Please remove this file manually (you may need to reboot to free file handles)
# WARNING conda.gateways.disk.delete:unlink_or_rename_to_trash(140): Could not remove or rename /opt/conda/pkgs/ncurses-6.2-he6710b0_1/lib/libmenu.so.6.  Please remove this file manually (you may need to reboot to free file handles)
# WARNING conda.gateways.disk.delete:unlink_or_rename_to_trash(140): Could not remove or rename /opt/conda/pkgs/ncurses-6.2-he6710b0_1/lib/libformw.so.6.2.  Please remove this file manually (you may need to reboot to free file handles)
# WARNING conda.gateways.disk.delete:unlink_or_rename_to_trash(140): Could not remove or rename /opt/conda/pkgs/ncurses-6.2-he6710b0_1/lib/libpanel.a.  Please remove this file manually (you may need to reboot to free file handles)
# WARNING conda.gateways.disk.delete:unlink_or_rename_to_trash(140): Could not remove or rename /opt/conda/pkgs/ncurses-6.2-he6710b0_1/lib/libmenuw.so.6.2.  Please remove this file manually (you may need to reboot to free file handles)
# WARNING conda.gateways.disk.delete:unlink_or_rename_to_trash(140): Could not remove or rename /opt/conda/pkgs/ncurses-6.2-he6710b0_1/lib/libncursesw.so.  Please remove this file manually (you may need to reboot to free file handles)
# WARNING conda.gateways.disk.delete:unlink_or_rename_to_trash(140): Could not remove or rename /opt/conda/pkgs/ncurses-6.2-he6710b0_1/lib/libncursesw.so.6.  Please remove this file manually (you may need to reboot to free file handles)
# WARNING conda.gateways.disk.delete:unlink_or_rename_to_trash(140): Could not remove or rename /opt/conda/pkgs/ncurses-6.2-he6710b0_1/lib/libtinfow.so.  Please remove this file manually (you may need to reboot to free file handles)
# WARNING conda.gateways.disk.delete:unlink_or_rename_to_trash(140): Could not remove or rename /opt/conda/pkgs/ncurses-6.2-he6710b0_1/lib/libncursesw.a.  Please remove this file manually (you may need to reboot to free file handles)
# WARNING conda.gateways.disk.delete:unlink_or_rename_to_trash(140): Could not remove or rename /opt/conda/pkgs/ncurses-6.2-he6710b0_1/lib/libmenu.so.6.2.  Please remove this file manually (you may need to reboot to free file handles)
# WARNING conda.gateways.disk.delete:unlink_or_rename_to_trash(140): Could not remove or rename /opt/conda/pkgs/ncurses-6.2-he6710b0_1/lib/libmenu.so.  Please remove this file manually (you may need to reboot to free file handles)
# WARNING conda.gateways.disk.delete:unlink_or_rename_to_trash(140): Could not remove or rename /opt/conda/pkgs/ncurses-6.2-he6710b0_1/lib/libpanelw.a.  Please remove this file manually (you may need to reboot to free file handles)
# WARNING conda.gateways.disk.delete:unlink_or_rename_to_trash(140): Could not remove or rename /opt/conda/pkgs/ncurses-6.2-he6710b0_1/lib/libtinfo.so.  Please remove this file manually (you may need to reboot to free file handles)
# ncurses-6.2          | 1.1 MB    | ##################################### | 100%
# pymssql-2.1.5        | 228 KB    | ##################################### | 100%
#
# InvalidArchiveError('Error with archive /opt/conda/pkgs/pyparsing-2.4.7-py_0.tar.bz2.  You probably need to delete and re-download or re-create this file.  Message from libarchive was:\n\nCould not unlink')
# InvalidArchiveError('Error with archive /opt/conda/pkgs/libxcb-1.14-h7b6447c_0.tar.bz2.  You probably need to delete and re-download or re-create this file.  Message from libarchive was:\n\nCould not unlink')
# InvalidArchiveError('Error with archive /opt/conda/pkgs/jupyterlab-2.2.6-py_0.tar.bz2.  You probably need to delete and re-download or re-create this file.  Message from libarchive was:\n\nCould not unlink')
# InvalidArchiveError('Error with archive /opt/conda/pkgs/libuuid-1.0.3-h1bed415_2.tar.bz2.  You probably need to delete and re-download or re-create this file.  Message from libarchive was:\n\nCould not unlink')
# InvalidArchiveError('Error with archive /opt/conda/pkgs/fontconfig-2.13.0-h9420a91_0.tar.bz2.  You probably need to delete and re-download or re-create this file.  Message from libarchive was:\n\nCould not unlink')
# InvalidArchiveError('Error with archive /opt/conda/pkgs/libpng-1.6.37-hbc83047_0.tar.bz2.  You probably need to delete and re-download or re-create this file.  Message from libarchive was:\n\nCould not unlink')
# InvalidArchiveError('Error with archive /opt/conda/pkgs/defusedxml-0.6.0-py_0.tar.bz2.  You probably need to delete and re-download or re-create this file.  Message from libarchive was:\n\nCould not unlink')
# InvalidArchiveError('Error with archive /opt/conda/pkgs/pickleshare-0.7.5-py37_1001.tar.bz2.  You probably need to delete and re-download or re-create this file.  Message from libarchive was:\n\nCould not unlink')
# InvalidArchiveError('Error with archive /opt/conda/pkgs/webencodings-0.5.1-py37_1.tar.bz2.  You probably need to delete and re-download or re-create this file.  Message from libarchive was:\n\nCould not unlink')
# InvalidArchiveError('Error with archive /opt/conda/pkgs/lz4-c-1.9.2-heb0550a_3.tar.bz2.  You probably need to delete and re-download or re-create this file.  Message from libarchive was:\n\nCould not unlink')
# InvalidArchiveError('Error with archive /opt/conda/pkgs/mistune-0.8.4-py37h14c3975_1001.tar.bz2.  You probably need to delete and re-download or re-create this file.  Message from libarchive was:\n\nCould not unlink')
# InvalidArchiveError('Error with archive /opt/conda/pkgs/libtiff-4.1.0-h2733197_1.tar.bz2.  You probably need to delete and re-download or re-create this file.  Message from libarchive was:\n\nCould not unlink')
# InvalidArchiveError('Error with archive /opt/conda/pkgs/markupsafe-1.1.1-py37h14c3975_1.tar.bz2.  You probably need to delete and re-download or re-create this file.  Message from libarchive was:\n\nCould not unlink')
# InvalidArchiveError('Error with archive /opt/conda/pkgs/pyjwt-1.7.1-py37_0.tar.bz2.  You probably need to delete and re-download or re-create this file.  Message from libarchive was:\n\nCould not unlink')
# InvalidArchiveError('Error with archive /opt/conda/pkgs/packaging-20.4-py_0.tar.bz2.  You probably need to delete and re-download or re-create this file.  Message from libarchive was:\n\nCould not unlink')
# InvalidArchiveError('Error with archive /opt/conda/pkgs/icu-58.2-he6710b0_3.tar.bz2.  You probably need to delete and re-download or re-create this file.  Message from libarchive was:\n\nCould not unlink')
# InvalidArchiveError('Error with archive /opt/conda/pkgs/pandocfilters-1.4.2-py37_1.tar.bz2.  You probably need to delete and re-download or re-create this file.  Message from libarchive was:\n\nCould not unlink')
# InvalidArchiveError('Error with archive /opt/conda/pkgs/argon2-cffi-20.1.0-py37h7b6447c_1.tar.bz2.  You probably need to delete and re-download or re-create this file.  Message from libarchive was:\n\nCould not unlink')
# InvalidArchiveError('Error with archive /opt/conda/pkgs/entrypoints-0.3-py37_0.tar.bz2.  You probably need to delete and re-download or re-create this file.  Message from libarchive was:\n\nCould not unlink')
# InvalidArchiveError('Error with archive /opt/conda/pkgs/send2trash-1.5.0-py37_0.tar.bz2.  You probably need to delete and re-download or re-create this file.  Message from libarchive was:\n\nCould not unlink')
# InvalidArchiveError('Error with archive /opt/conda/pkgs/libxml2-2.9.10-hb55368b_3.tar.bz2.  You probably need to delete and re-download or re-create this file.  Message from libarchive was:\n\nCould not unlink')
# InvalidArchiveError('Error with archive /opt/conda/pkgs/ipython_genutils-0.2.0-py37_0.tar.bz2.  You probably need to delete and re-download or re-create this file.  Message from libarchive was:\n\nCould not unlink')
# InvalidArchiveError('Error with archive /opt/conda/pkgs/ncurses-6.2-he6710b0_1.tar.bz2.  You probably need to delete and re-download or re-create this file.  Message from libarchive was:\n\nCould not unlink')

# %%
import seaborn as sns

bins = np.linspace(df1.BARTHAG.min(), df1.BARTHAG.max(), 10)
g = sns.FacetGrid(df1, col="windex", hue="POSTSEASON", palette="Set1", col_wrap=2)
g.map(plt.hist, 'BARTHAG', bins=bins, ec="k")

g.axes[-1].legend()
plt.show()

# %%
bins = np.linspace(df1.ADJOE.min(), df1.ADJOE.max(), 10)
g = sns.FacetGrid(df1, col="windex", hue="POSTSEASON", palette="Set1", col_wrap=2)
g.map(plt.hist, 'ADJOE', bins=bins, ec="k")

g.axes[-1].legend()
plt.show()

# %% [markdown]
# # Pre-processing:  Feature selection/extraction

# %% [markdown]
# ### Lets look at how Adjusted Defense Efficiency plots

# %%
bins = np.linspace(df1.ADJDE.min(), df1.ADJDE.max(), 10)
g = sns.FacetGrid(df1, col="windex", hue="POSTSEASON", palette="Set1", col_wrap=2)
g.map(plt.hist, 'ADJDE', bins=bins, ec="k")
g.axes[-1].legend()
plt.show()

# %% [markdown]
# We see that this data point doesn't impact the ability of a team to get into the Final Four.

# %% [markdown]
# ## Convert Categorical features to numerical values

# %% [markdown]
# Lets look at the postseason:

# %%
df1.groupby(['windex'])['POSTSEASON'].value_counts(normalize=True)
# Out:
# windex  POSTSEASON
# False   S16           0.605263
#         E8            0.263158
#         F4            0.131579
# True    S16           0.500000
#         E8            0.333333
#         F4            0.166667
# Name: POSTSEASON, dtype: float64

# %% [markdown]
# 13% of teams with 6 or less wins above bubble make it into the final four while 17% of teams with 7 or more do.

# %% [markdown]
# Lets convert wins above bubble (winindex) under 7 to 0 and over 7 to 1:

# %%
df1['windex'].replace(to_replace=['False','True'], value=[0,1],inplace=True)
df1.head()
# Out:
# /opt/conda/envs/Python-3.7-main/lib/python3.7/site-packages/pandas/core/generic.py:6746: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._update_inplace(new_data)
#          TEAM CONF   G   W  ADJOE  ADJDE  BARTHAG  EFG_O  EFG_D   TOR  ...  \
# 2  Notre Dame  ACC  36  24  118.3  103.3   0.8269   54.0   49.5  15.3  ...
# 3    Virginia  ACC  37  29  119.9   91.0   0.9600   54.8   48.4  15.1  ...
# 4      Kansas  B12  37  32  120.9   90.4   0.9662   55.7   45.1  17.8  ...
# 5      Oregon  P12  37  30  118.4   96.2   0.9163   52.3   48.9  16.1  ...
# 6    Syracuse  ACC  37  23  111.9   93.6   0.8857   50.0   47.3  18.1  ...
#
#    2P_O  2P_D  3P_O  3P_D  ADJ_T   WAB  POSTSEASON  SEED  YEAR  windex
# 2  52.9  46.5  37.4  36.9   65.5   2.3          E8   6.0  2016       0
# 3  52.6  46.3  40.3  34.7   61.9   8.6          E8   1.0  2016       1
# 4  52.7  43.4  41.3  32.5   70.1  11.6          E8   1.0  2016       1
# 5  52.6  46.1  34.4  36.2   69.0   6.7          E8   1.0  2016       0
# 6  47.2  48.1  36.0  30.7   65.5  -0.3          F4  10.0  2016       0
#
# [5 rows x 25 columns]

# %% [markdown]
# ### Feature selection

# %% [markdown]
# Lets defind feature sets, X:

# %%
X = df1[['G', 'W', 'ADJOE', 'ADJDE', 'BARTHAG', 'EFG_O', 'EFG_D',
       'TOR', 'TORD', 'ORB', 'DRB', 'FTR', 'FTRD', '2P_O', '2P_D', '3P_O',
       '3P_D', 'ADJ_T', 'WAB', 'SEED', 'windex']]
X[0:5]
# Out:
#     G   W  ADJOE  ADJDE  BARTHAG  EFG_O  EFG_D   TOR  TORD   ORB  ...   FTR  \
# 2  36  24  118.3  103.3   0.8269   54.0   49.5  15.3  14.8  32.7  ...  32.9
# 3  37  29  119.9   91.0   0.9600   54.8   48.4  15.1  18.8  29.9  ...  32.1
# 4  37  32  120.9   90.4   0.9662   55.7   45.1  17.8  18.5  32.2  ...  38.6
# 5  37  30  118.4   96.2   0.9163   52.3   48.9  16.1  20.2  34.1  ...  40.3
# 6  37  23  111.9   93.6   0.8857   50.0   47.3  18.1  20.4  33.5  ...  35.4
#
#    FTRD  2P_O  2P_D  3P_O  3P_D  ADJ_T   WAB  SEED  windex
# 2  26.0  52.9  46.5  37.4  36.9   65.5   2.3   6.0       0
# 3  33.4  52.6  46.3  40.3  34.7   61.9   8.6   1.0       1
# 4  37.3  52.7  43.4  41.3  32.5   70.1  11.6   1.0       1
# 5  32.0  52.6  46.1  34.4  36.2   69.0   6.7   1.0       0
# 6  28.0  47.2  48.1  36.0  30.7   65.5  -0.3  10.0       0
#
# [5 rows x 21 columns]

# %% [markdown]
# What are our lables? Round where the given team was eliminated or where their season ended (R68 = First Four, R64 = Round of 64, R32 = Round of 32, S16 = Sweet Sixteen, E8 = Elite Eight, F4 = Final Four, 2ND = Runner-up, Champion = Winner of the NCAA March Madness Tournament for that given year)|

# %%
y = df1['POSTSEASON'].values
y[0:5]
# Out:
# array(['E8', 'E8', 'E8', 'E8', 'F4'], dtype=object)

# %% [markdown]
# ## Normalize Data

# %% [markdown]
# Data Standardization give data zero mean and unit variance (technically should be done after train test split )

# %%
X= preprocessing.StandardScaler().fit(X).transform(X)
X[0:5]
# Out:
# array([[-0.43331874, -1.26140173,  0.28034482,  2.74329908, -2.45717765,
#          0.10027963,  0.94171924, -1.16188145, -1.71391372,  0.12750511,
#          1.33368704, -0.4942211 , -0.87998988,  0.02784185,  0.00307239,
#          0.22576157,  1.59744386, -1.12106011, -1.0448016 ,  0.49716104,
#         -0.6882472 ],
#        [ 0.40343468,  0.35874728,  0.64758014, -0.90102957,  1.127076  ,
#          0.39390887,  0.38123706, -1.29466791, -0.03522254, -0.62979797,
#         -1.31585883, -0.68542235,  0.55458056, -0.07167795, -0.0829545 ,
#          1.32677295,  0.65081046, -2.369021  ,  0.98050611, -1.14054592,
#          1.45296631],
#        [ 0.40343468,  1.33083669,  0.87710222, -1.0788017 ,  1.29403598,
#          0.72424177, -1.30020946,  0.49794919, -0.16112438, -0.00772758,
#         -0.27908001,  0.86808783,  1.31063795, -0.03850468, -1.33034432,
#          1.70643205, -0.29582294,  0.47355659,  1.94493836, -1.14054592,
#          1.45296631],
#        [ 0.40343468,  0.68277708,  0.30329703,  0.63966222, -0.04972253,
#         -0.52368251,  0.63600169, -0.63073565,  0.55231938,  0.50615665,
#          0.71929959,  1.2743905 ,  0.28317534, -0.07167795, -0.16898138,
#         -0.91321572,  1.29624232,  0.0922352 ,  0.36969903, -1.14054592,
#         -0.6882472 ],
#        [ 0.40343468, -1.58543153, -1.18859646, -0.13068368, -0.87375079,
#         -1.36786658, -0.17924511,  0.69712887,  0.63625394,  0.34387742,
#          2.56246194,  0.10328282, -0.49226814, -1.8630343 ,  0.69128747,
#         -0.30576117, -1.07034117, -1.12106011, -1.88064288,  1.80732661,
#         -0.6882472 ]])

# %% [markdown]
# ## Training and Validation

# %% [markdown]
# Split the data into Training and Validation data.

# %%
# We split the X into train and test to find the best k
from sklearn.model_selection import train_test_split
X_train, X_val, y_train, y_val = train_test_split(X, y, test_size=0.2, random_state=4)
print ('Train set:', X_train.shape,  y_train.shape)
print ('Validation set:', X_val.shape,  y_val.shape)
# Out:
# Train set: (44, 21) (44,)
# Validation set: (12, 21) (12,)

# %% [markdown]
# # Classification

# %% [markdown]
# Now, it is your turn, use the training set to build an accurate model. Then use the validation set  to report the accuracy of the model
# You should use the following algorithm:
#
# -   K Nearest Neighbor(KNN)
# -   Decision Tree
# -   Support Vector Machine
# -   Logistic Regression

# %% [markdown]
# # K Nearest Neighbor(KNN)
#
# <b>Question  1 </b> Build a KNN model using a value of k equals five, find the accuracy on the validation data (X_val and y_val)

# %% [markdown]
# You can use <code> accuracy_score</cdoe>

# %%
from sklearn.metrics import accuracy_score
from sklearn.neighbors import KNeighborsClassifier

# %% [markdown]
# <b>Question  2</b> Determine and print the accuracy for the first 15 values of k the on the validation data:

# %%
k = 5

neigh = KNeighborsClassifier(n_neighbors = k).fit(X_train,y_train)
neigh
yhat = neigh.predict(X_val)
print(yhat[0:18])
print("Train set Accuracy: ", accuracy_score(y_train, neigh.predict(X_train)))
print("Test set Accuracy: ", accuracy_score(y_val, yhat))
# Out:
# ['S16' 'S16' 'S16' 'E8' 'E8' 'E8' 'S16' 'F4' 'S16' 'S16' 'S16' 'S16']
# Train set Accuracy:  0.6363636363636364
# Test set Accuracy:  0.6666666666666666

# %% [markdown]
# # Decision Tree

# %% [markdown]
# The following lines of code fit a <code>DecisionTreeClassifier</code>:

# %%
from sklearn.tree import DecisionTreeClassifier

# %% [markdown]
# <b>Question  3</b> Determine the minumum   value for the parameter <code>max_depth</code> that improves results

# %%
xxx = DecisionTreeClassifier(criterion="entropy", max_depth = 1)
xxx.fit(X_train,y_train)
yyy=xxx.predict(X_val)
print (yyy[0:18])
print (y_val[0:18])
# Out:
# ['S16' 'S16' 'S16' 'S16' 'S16' 'S16' 'S16' 'E8' 'S16' 'S16' 'S16' 'S16']
# ['F4' 'S16' 'S16' 'S16' 'S16' 'E8' 'S16' 'F4' 'S16' 'E8' 'S16' 'S16']

# %% [markdown]
# # Support Vector Machine

# %% [markdown]
# <b>Question  4</b>Train the support  vector machine model and determine the accuracy on the validation data for each kernel. Find the kernel (linear, poly, rbf, sigmoid) that provides the best score on the validation data and train a SVM using it.

# %%
from sklearn import svm
from sklearn.metrics import classification_report, confusion_matrix

# %%
clf = svm.SVC(kernel='poly')
clf.fit(X_train, y_train) 
yhat1 = clf.predict(X_val)
yhat1 [0:18]




print('SVM Accuracy:',accuracy_score(y_val,yhat1))
# Out:
# SVM Accuracy: 0.6666666666666666

# %% [markdown]
# # Logistic Regression

# %% [markdown]
# <b>Question 5</b> Train a logistic regression model and determine the accuracy of the validation data (set C=0.01)

# %%
from sklearn.linear_model import LogisticRegression

# %%
LR = LogisticRegression(C=0.01, solver='liblinear').fit(X_train,y_train)
LR
yhat2 = LR.predict(X_val)
yhat2
yhat_prob = LR.predict_proba(X_val)
yhat_prob
print("LR: ", accuracy_score(y_val, yhat))
# Out:
# LR:  0.6666666666666666

# %% [markdown]
# # Model Evaluation using Test set

# %%
from sklearn.metrics import f1_score
# for f1_score please set the average parameter to 'micro'
from sklearn.metrics import log_loss

# %%
def jaccard_index(predictions, true):
    if (len(predictions) == len(true)):
        intersect = 0;
        for x,y in zip(predictions, true):
            if (x == y):
                intersect += 1
        return intersect / (len(predictions) + len(true) - intersect)
    else:
        return -1

# %% [markdown]
# <b>Question  5</b> Calculate the  F1 score and Jaccard Similarity score for each model from above. Use the Hyperparameter that performed best on the validation data. **For f1_score please set the average parameter to 'micro'.**

# %% [markdown]
# ### Load Test set for evaluation

# %%
test_df = pd.read_csv('https://s3-api.us-geo.objectstorage.softlayer.net/cf-courses-data/CognitiveClass/ML0120ENv3/Dataset/ML0101EN_EDX_skill_up/basketball_train.csv',error_bad_lines=False)
test_df.head()
# Out:
#              TEAM CONF   G   W  ADJOE  ADJDE  BARTHAG  EFG_O  EFG_D   TOR  \
# 0  North Carolina  ACC  40  33  123.3   94.9   0.9531   52.6   48.1  15.4
# 1       Villanova   BE  40  35  123.1   90.9   0.9703   56.1   46.7  16.3
# 2      Notre Dame  ACC  36  24  118.3  103.3   0.8269   54.0   49.5  15.3
# 3        Virginia  ACC  37  29  119.9   91.0   0.9600   54.8   48.4  15.1
# 4          Kansas  B12  37  32  120.9   90.4   0.9662   55.7   45.1  17.8
#
#    ...  FTRD  2P_O  2P_D  3P_O  3P_D  ADJ_T   WAB  POSTSEASON  SEED  YEAR
# 0  ...  30.4  53.9  44.6  32.7  36.2   71.7   8.6         2ND   1.0  2016
# 1  ...  30.0  57.4  44.1  36.2  33.9   66.7   8.9   Champions   2.0  2016
# 2  ...  26.0  52.9  46.5  37.4  36.9   65.5   2.3          E8   6.0  2016
# 3  ...  33.4  52.6  46.3  40.3  34.7   61.9   8.6          E8   1.0  2016
# 4  ...  37.3  52.7  43.4  41.3  32.5   70.1  11.6          E8   1.0  2016
#
# [5 rows x 24 columns]

# %%
test_df['windex'] = np.where(test_df.WAB > 7, 'True', 'False')
test_df1 = test_df[test_df['POSTSEASON'].str.contains('F4|S16|E8', na=False)]
test_Feature = test_df1[['G', 'W', 'ADJOE', 'ADJDE', 'BARTHAG', 'EFG_O', 'EFG_D',
       'TOR', 'TORD', 'ORB', 'DRB', 'FTR', 'FTRD', '2P_O', '2P_D', '3P_O',
       '3P_D', 'ADJ_T', 'WAB', 'SEED', 'windex']]
test_Feature['windex'].replace(to_replace=['False','True'], value=[0,1],inplace=True)
test_X=test_Feature
test_X= preprocessing.StandardScaler().fit(test_X).transform(test_X)
test_X[0:5]
# Out:
# /opt/conda/envs/Python-3.7-main/lib/python3.7/site-packages/pandas/core/generic.py:6746: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._update_inplace(new_data)
# array([[-4.08074446e-01, -1.10135297e+00,  3.37365934e-01,
#          2.66479976e+00, -2.46831661e+00,  2.13703245e-01,
#          9.44090550e-01, -1.19216365e+00, -1.64348924e+00,
#          1.45405982e-02,  1.29523097e+00, -6.23533182e-01,
#         -9.31788560e-01,  1.42784371e-01,  1.68876201e-01,
#          2.84500844e-01,  1.62625961e+00, -8.36649260e-01,
#         -9.98500539e-01,  4.84319174e-01, -6.77003200e-01],
#        [ 3.63958290e-01,  3.26326807e-01,  7.03145068e-01,
#         -7.13778644e-01,  1.07370841e+00,  4.82633172e-01,
#          4.77498943e-01, -1.32975879e+00, -6.86193316e-02,
#         -7.35448152e-01, -1.35447914e+00, -8.06829025e-01,
#          3.41737757e-01,  4.96641291e-02,  9.40576311e-02,
#          1.37214061e+00,  6.93854620e-01, -2.00860931e+00,
#          9.80549967e-01, -1.19401460e+00,  1.47709789e+00],
#        [ 3.63958290e-01,  1.18293467e+00,  9.31757027e-01,
#         -8.78587347e-01,  1.23870131e+00,  7.85179340e-01,
#         -9.22275877e-01,  5.27775662e-01, -1.86734575e-01,
#         -1.19385964e-01, -3.17636057e-01,  6.82449703e-01,
#          1.01292055e+00,  8.07042098e-02, -9.90811637e-01,
#          1.74718880e+00, -2.38550367e-01,  6.60855252e-01,
#          1.92295497e+00, -1.19401460e+00,  1.47709789e+00],
#        [ 3.63958290e-01,  6.11862762e-01,  3.60227129e-01,
#          7.14563447e-01, -8.92254236e-02, -3.57772849e-01,
#          6.89586037e-01, -6.41783067e-01,  4.82585136e-01,
#          3.89534973e-01,  6.80805434e-01,  1.07195337e+00,
#          1.00800346e-01,  4.96641291e-02,  1.92390609e-02,
#         -8.40643737e-01,  1.32958529e+00,  3.02756347e-01,
#          3.83693465e-01, -1.19401460e+00, -6.77003200e-01],
#        [ 3.63958290e-01, -1.38688893e+00, -1.12575060e+00,
#          3.92401673e-04, -9.03545224e-01, -1.13094639e+00,
#          1.09073363e-02,  7.34168378e-01,  5.61328631e-01,
#          2.28823098e-01,  2.52408203e+00, -5.07336709e-02,
#         -5.87592258e-01, -1.62650023e+00,  7.67424763e-01,
#         -2.40566627e-01, -1.00142717e+00, -8.36649260e-01,
#         -1.81525154e+00,  1.82698619e+00, -6.77003200e-01]])

# %%
test_y = test_df1['POSTSEASON'].values
test_y[0:5]
# Out:
# array(['E8', 'E8', 'E8', 'E8', 'F4'], dtype=object)

# %% [markdown]
# KNN

# %%
yhat1 = neigh.predict(test_X)
print(yhat1[0:18])
print('KNN f1 score:',f1_score(test_y, yhat1, average='micro'))
print('KNN Jaccord score:',jaccard_index(test_y, yhat1))
# Out:
# ['S16' 'S16' 'E8' 'E8' 'E8' 'E8' 'S16' 'S16' 'S16' 'S16' 'S16' 'S16' 'E8'
#  'S16' 'E8' 'E8' 'E8' 'E8']
# KNN f1 score: 0.6285714285714286
# KNN Jaccord score: 0.4583333333333333

# %% [markdown]
# Decision Tree

# %%
yyy1=xxx.predict(test_X)
print (yyy1[0:18])
print("DecisionTrees's F1 Score: ", f1_score(test_y, yyy1, average='micro'))
print('DecisionTree Jaccord score:',jaccard_index(test_y, yyy1))
# Out:
# ['S16' 'E8' 'E8' 'E8' 'S16' 'S16' 'S16' 'S16' 'S16' 'S16' 'S16' 'S16'
#  'S16' 'S16' 'E8' 'S16' 'S16' 'S16']
# DecisionTrees's F1 Score:  0.6428571428571429
# DecisionTree Jaccord score: 0.47368421052631576

# %% [markdown]
# SVM

# %%
yhat2 = clf.predict(test_X)
yhat1 [0:18]
print("SVM F1 Score: ", f1_score(test_y, yhat2, average='micro'))
print('SVM Jaccord score:',jaccard_index(test_y, yhat2))
# Out:
# SVM F1 Score:  0.6857142857142857
# SVM Jaccord score: 0.5217391304347826

# %% [markdown]
# Logistic Regression

# %%
yhat3 = LR.predict(test_X)
print("LR F1 Score: ", f1_score(test_y, yhat3, average='micro'))
print('LR Jaccord score:',jaccard_index(test_y, yhat3))
# Out:
# LR F1 Score:  0.6857142857142857
# LR Jaccord score: 0.5217391304347826

# %% [markdown]
# # Final Report
# The accuracy of the built model using different evaluation metrics:

# %% [markdown]
# | Algorithm          | Accuracy | Jaccard  | F1-score | LogLoss |
# | ------------------ | -------- | -------- | -------- | ------- |
# | KNN                | 0.628571 | 0.458333 | 0.628571 | NA      |
# | Decision Tree      | 0.642857 | 0.473684 | 0.642857 | NA      |
# | SVM                | 0.685714 | 0.521739 | 0.685714 | NA      |
# | LogisticRegression | 0.685714 | 0.521739 | 0.685714 | 1.03719 |

# %% [markdown]
# Something to keep in mind when creating models to predict the results of basketball tournaments or sports in general is that is quite hard due to so many factors influencing the game. Even in sports betting an accuracy of 55% and over is considered good as it indicates profits.
